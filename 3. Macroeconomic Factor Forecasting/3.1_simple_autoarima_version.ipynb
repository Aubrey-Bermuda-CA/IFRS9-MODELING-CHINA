# %% [markdown]
# *https://github.com/Aubrey-Bermuda-CA/IFRS9-MODELING-CHINA*

# %% [markdown]
# *3.1 Function description: Read macro historical data and external prediction data, use autoarima to predict macro data.*

# %%
import time
import pandas as pd
import pmdarima as pm

# %%
# set date range
start_date = '2010-03-31'
forecast_date = '2026-09-30'
date_index = pd.date_range(start=start_date, end=forecast_date, freq='Q')

# read macro data
macro_his_data = pd.read_csv(f'./macrofactor_historical_data.csv', index_col=[0], parse_dates=[0])
macro_fc_data = pd.read_csv(f'./macrofactor_forecast_data.csv', index_col=[0], parse_dates=[0])

# combine data
macro_data = macro_his_data.combine_first(macro_fc_data)

# Missing values ​​can be handled using interpolation. There are several methods to choose from:
# 'linear', 'nearest', 'zero', 'slinear', 'quadratic', 'cubic', 'barycentric', 'polynomial', 
# 'krogh', 'piecewise_polynomial', 'spline', 'pchip', 'akima', 'cubicspline'
# macro_data = macro_data.interpolate(method='spline')

macro_data
# Out:
#             GDP_Const_Qtr  Ind_Pro_Mth  CPI_Mth  Core_CPI_Mth  PPI_Mth  \
# date
# 2010-03-31          12.20         18.1  102.400           NaN     5.91
# 2010-06-30          10.80         13.7  102.900           NaN     6.41
# 2010-09-30           9.90         13.3  103.600           NaN     4.33
# 2010-12-31           9.90         13.5  104.600           NaN     5.93
# 2011-03-31          10.20         14.8  105.383           NaN     7.31
# ...                   ...          ...      ...           ...      ...
# 2024-09-30           4.60          5.4  100.400           0.1    -2.80
# 2024-12-31           4.85          NaN    1.800           0.7    -2.20
# 2025-03-31           4.00          NaN      NaN           NaN      NaN
# 2025-06-30           4.55          NaN      NaN           NaN      NaN
# 2025-09-30           4.20          NaN      NaN           NaN      NaN
#
#             FAI_Cum  Retail_Sales_Mth  Imports_Mth  Exports_Mth     M1  ...  \
# date                                                                    ...
# 2010-03-31     26.4             18.00        66.27        24.21  29.94  ...
# 2010-06-30     25.5             18.30        33.87        43.87  24.56  ...
# 2010-09-30     24.5             18.84        24.38        25.08  20.87  ...
# 2010-12-31     24.5             19.10        25.94        17.87  21.19  ...
# 2011-03-31     25.0             17.40        27.50        35.76  15.00  ...
# ...             ...               ...          ...          ...    ...  ...
# 2024-09-30      3.4              3.20         0.30         2.40  -7.40  ...
# 2024-12-31      3.0              6.40        11.00          NaN  -6.50  ...
# 2025-03-31      3.6               NaN          NaN          NaN    NaN  ...
# 2025-06-30      3.9               NaN          NaN          NaN    NaN  ...
# 2025-09-30      4.0               NaN          NaN          NaN    NaN  ...
#
#             PPIRM_Mth  CGPI_Mth  70_Cities_Price_Mth  Power_Gen_Mth  \
# date
# 2010-03-31      11.46     105.6                  9.5           17.6
# 2010-06-30      10.80     106.6                  7.7           11.4
# 2010-09-30       7.10     106.1                  6.2            8.1
# 2010-12-31       9.47     107.9                  5.0            5.1
# 2011-03-31      10.53     109.3                  3.7           14.8
# ...               ...       ...                  ...            ...
# 2024-09-30      -2.20      98.3                 -9.0            6.0
# 2024-12-31        NaN       NaN                  NaN            NaN
# 2025-03-31        NaN       NaN                  NaN            NaN
# 2025-06-30        NaN       NaN                  NaN            NaN
# 2025-09-30        NaN       NaN                  NaN            NaN
#
#             Freight_Mth  Urban_Income_Cum  Urban_Exp_Cum  Nat_Housing_Index  \
# date
# 2010-03-31    15.800000               9.8          11.01             105.89
# 2010-06-30    12.300000              10.2           9.89             105.06
# 2010-09-30    11.900000              10.5           9.32             103.52
# 2010-12-31     0.310000              11.3           9.84             101.79
# 2011-03-31    14.300000              12.3          10.69             102.98
# ...                 ...               ...            ...                ...
# 2024-09-30     2.315156               4.5           5.00              92.40
# 2024-12-31          NaN               NaN            NaN                NaN
# 2025-03-31          NaN               NaN            NaN                NaN
# 2025-06-30          NaN               NaN            NaN                NaN
# 2025-09-30          NaN               NaN            NaN                NaN
#
#             Macro_Eco_Index  Housing_Sales_Cum
# date
# 2010-03-31            104.0               57.7
# 2010-06-30            102.6               25.4
# 2010-09-30            101.9               15.9
# 2010-12-31            103.6               18.3
# 2011-03-31            102.5               27.3
# ...                     ...                ...
# 2024-09-30              NaN              -22.7
# 2024-12-31              NaN                NaN
# 2025-03-31              NaN                NaN
# 2025-06-30              NaN                NaN
# 2025-09-30              NaN                NaN
#
# [63 rows x 25 columns]

# %%
# macrofactor forecast with autoarima
df = macro_data
predict_data = pd.DataFrame(index=date_index)
print(f'macrofoctor_list：{df.columns.values}')

# timer
start_t = time.perf_counter()

# fitmodel
for column in df:
    y = df[column].dropna()
    # seasonal data use 4
    m = 4
    # calc d and D firt to save time
    d = pm.arima.ndiffs(y, alpha=0.05, test='adf', max_d=2)
    D = pm.arima.nsdiffs(y, m=m, test='ocsb', max_D=2)
    print(f'Traverse {column} equation...')
    arima = pm.auto_arima(y, m=m, method='lbfgs', # 'newton', 'nm', 'bfgs', 'lbfgs', 'powell', 'cg', 'ncg', 'basinhopping'
                          start_p=1, start_q=1, d=d, 
                          start_P=1, start_Q=1, D=D,
                          max_p=5, max_q=5, 
                          max_P=5, max_Q=5,
                          seasonal=True, alpha=0.05,
                          information_criterion='aic', # 'aic', 'bic', 'hqic', 'oob'
                          stepwise=True, # The stepwise algorithm can be significantly faster than fitting all
                          error_action='ignore', 
                          suppress_warnings=True,
                          trace=True
                          )
    # predict
    pr_in = arima.predict_in_sample(X=None, dynamic=False, return_conf_int=False)
    pr_out = arima.predict(n_periods=15, X=None, return_conf_int=False)
    pr = pd.DataFrame({column:pd.concat([pr_in, pr_out])})
    predict_data = predict_data.merge(pr, left_index=True, right_index=True, how='left')

# Output prediction results
predict_data = macro_data.combine_first(predict_data)
predict_data.to_csv(f'./3.1_predict_data.csv')

dur = (time.perf_counter() - start_t) / 60
print(f'The prediction process took a total of {dur:,.2f} minutes.')
# Out:
# macrofoctor_list：['GDP_Const_Qtr' 'Ind_Pro_Mth' 'CPI_Mth' 'Core_CPI_Mth' 'PPI_Mth'
#  'FAI_Cum' 'Retail_Sales_Mth' 'Imports_Mth' 'Exports_Mth' 'M1' 'M2'
#  'Loans_RMB' 'Social_Financing' 'Manuf_PMI' 'Ind_Revenue_Cum' 'PPIRM_Mth'
#  'CGPI_Mth' '70_Cities_Price_Mth' 'Power_Gen_Mth' 'Freight_Mth'
#  'Urban_Income_Cum' 'Urban_Exp_Cum' 'Nat_Housing_Index' 'Macro_Eco_Index'
#  'Housing_Sales_Cum']
# Traverse GDP_Const_Qtr equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=322.792, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=304.362, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=312.425, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=430.838, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=308.477, Time=0.02 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=304.825, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,1)[4] intercept   : AIC=302.254, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,2)[4] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(1,0,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,1)[4] intercept   : AIC=324.171, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,1)[4] intercept   : AIC=296.782, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[4] intercept   : AIC=309.681, Time=0.03 sec
#  ARIMA(2,0,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(2,0,0)(0,0,2)[4] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(2,0,0)(1,0,0)[4] intercept   : AIC=302.941, Time=0.06 sec
#  ARIMA(2,0,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(3,0,0)(0,0,1)[4] intercept   : AIC=297.695, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,1)[4] intercept   : AIC=295.979, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,0)[4] intercept   : AIC=311.681, Time=0.04 sec
#  ARIMA(2,0,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(2,0,1)(0,0,2)[4] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(2,0,1)(1,0,0)[4] intercept   : AIC=302.042, Time=0.14 sec
#  ARIMA(2,0,1)(1,0,2)[4] intercept   : AIC=301.027, Time=0.23 sec
#  ARIMA(1,0,1)(0,0,1)[4] intercept   : AIC=294.135, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[4] intercept   : AIC=309.814, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,2)[4] intercept   : AIC=296.062, Time=0.20 sec
#  ARIMA(1,0,1)(1,0,0)[4] intercept   : AIC=301.344, Time=0.10 sec
#  ARIMA(1,0,1)(1,0,2)[4] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(1,0,2)(0,0,1)[4] intercept   : AIC=295.997, Time=0.16 sec
#  ARIMA(0,0,2)(0,0,1)[4] intercept   : AIC=309.972, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,1)[4] intercept   : AIC=297.541, Time=0.17 sec
#  ARIMA(1,0,1)(0,0,1)[4]             : AIC=295.158, Time=0.05 sec
#
# Best model:  ARIMA(1,0,1)(0,0,1)[4] intercept
# Total fit time: 3.602 seconds
# Traverse Ind_Pro_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=249.542, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=268.555, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=251.303, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=246.204, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=267.049, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=260.742, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=248.033, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,2)[4] intercept   : AIC=248.072, Time=0.04 sec
#  ARIMA(0,1,1)(1,0,0)[4] intercept   : AIC=248.382, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,2)[4] intercept   : AIC=249.781, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,1)[4] intercept   : AIC=250.640, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,1)[4] intercept   : AIC=247.729, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,1)[4] intercept   : AIC=247.587, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=248.460, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,1)[4] intercept   : AIC=249.487, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[4]             : AIC=249.578, Time=0.02 sec
#
# Best model:  ARIMA(0,1,1)(0,0,1)[4] intercept
# Total fit time: 0.528 seconds
# Traverse CPI_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[4]             : AIC=416.278, Time=0.06 sec
#  ARIMA(0,2,0)(0,2,0)[4]             : AIC=410.550, Time=0.01 sec
#  ARIMA(1,2,0)(1,2,0)[4]             : AIC=412.685, Time=0.03 sec
#  ARIMA(0,2,1)(0,2,1)[4]             : AIC=413.440, Time=0.03 sec
#  ARIMA(0,2,0)(1,2,0)[4]             : AIC=410.735, Time=0.02 sec
#  ARIMA(0,2,0)(0,2,1)[4]             : AIC=411.443, Time=0.02 sec
#  ARIMA(0,2,0)(1,2,1)[4]             : AIC=412.464, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[4]             : AIC=412.549, Time=0.01 sec
#  ARIMA(0,2,1)(0,2,0)[4]             : AIC=412.549, Time=0.01 sec
#  ARIMA(1,2,1)(0,2,0)[4]             : AIC=414.549, Time=0.02 sec
#  ARIMA(0,2,0)(0,2,0)[4] intercept   : AIC=411.649, Time=0.01 sec
#
# Best model:  ARIMA(0,2,0)(0,2,0)[4]
# Total fit time: 0.258 seconds
# Traverse Core_CPI_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=-4.858, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=-3.214, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=-8.421, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=-8.645, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=-4.608, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=-1.217, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=-6.711, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,2)[4] intercept   : AIC=-6.678, Time=0.07 sec
#  ARIMA(0,1,1)(1,0,0)[4] intercept   : AIC=-8.409, Time=0.04 sec
#  ARIMA(0,1,1)(1,0,2)[4] intercept   : AIC=-6.456, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,1)[4] intercept   : AIC=-10.574, Time=0.03 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=-8.022, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,2)[4] intercept   : AIC=-8.580, Time=0.04 sec
#  ARIMA(0,1,0)(1,0,0)[4] intercept   : AIC=-10.043, Time=0.03 sec
#  ARIMA(0,1,0)(1,0,2)[4] intercept   : AIC=-8.219, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=-8.654, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,1)[4] intercept   : AIC=-6.755, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,1)[4]             : AIC=-10.149, Time=0.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,1)[4] intercept
# Total fit time: 1.119 seconds
# Traverse PPI_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=352.627, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=256.138, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=353.150, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=260.685, Time=0.01 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=247.285, Time=0.06 sec
#  ARIMA(1,0,0)(3,0,0)[4] intercept   : AIC=244.224, Time=0.13 sec
#  ARIMA(1,0,0)(4,0,0)[4] intercept   : AIC=245.918, Time=0.11 sec
#  ARIMA(1,0,0)(3,0,1)[4] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(1,0,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(1,0,0)(4,0,1)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(3,0,0)[4] intercept   : AIC=344.794, Time=0.05 sec
#  ARIMA(2,0,0)(3,0,0)[4] intercept   : AIC=224.787, Time=0.07 sec
#  ARIMA(2,0,0)(2,0,0)[4] intercept   : AIC=228.838, Time=0.06 sec
#  ARIMA(2,0,0)(4,0,0)[4] intercept   : AIC=226.578, Time=0.10 sec
#  ARIMA(2,0,0)(3,0,1)[4] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(2,0,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(2,0,0)(4,0,1)[4] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(3,0,0)(3,0,0)[4] intercept   : AIC=224.638, Time=0.09 sec
#  ARIMA(3,0,0)(2,0,0)[4] intercept   : AIC=228.353, Time=0.07 sec
#  ARIMA(3,0,0)(4,0,0)[4] intercept   : AIC=226.476, Time=0.14 sec
#  ARIMA(3,0,0)(3,0,1)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(3,0,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(3,0,0)(4,0,1)[4] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(3,0,1)(3,0,0)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(2,0,1)(3,0,0)[4] intercept   : AIC=220.862, Time=0.11 sec
#  ARIMA(2,0,1)(2,0,0)[4] intercept   : AIC=225.436, Time=0.08 sec
#  ARIMA(2,0,1)(4,0,0)[4] intercept   : AIC=222.402, Time=0.15 sec
#  ARIMA(2,0,1)(3,0,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(2,0,1)(2,0,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(2,0,1)(4,0,1)[4] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,1)(3,0,0)[4] intercept   : AIC=229.137, Time=0.08 sec
#  ARIMA(2,0,2)(3,0,0)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(1,0,2)(3,0,0)[4] intercept   : AIC=231.107, Time=0.11 sec
#  ARIMA(3,0,2)(3,0,0)[4] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(2,0,1)(3,0,0)[4]             : AIC=220.743, Time=0.08 sec
#  ARIMA(2,0,1)(2,0,0)[4]             : AIC=224.877, Time=0.06 sec
#  ARIMA(2,0,1)(4,0,0)[4]             : AIC=222.460, Time=0.13 sec
#  ARIMA(2,0,1)(3,0,1)[4]             : AIC=inf, Time=0.23 sec
#  ARIMA(2,0,1)(2,0,1)[4]             : AIC=inf, Time=0.22 sec
#  ARIMA(2,0,1)(4,0,1)[4]             : AIC=inf, Time=0.31 sec
#  ARIMA(1,0,1)(3,0,0)[4]             : AIC=227.896, Time=0.07 sec
#  ARIMA(2,0,0)(3,0,0)[4]             : AIC=223.681, Time=0.06 sec
#  ARIMA(3,0,1)(3,0,0)[4]             : AIC=inf, Time=0.24 sec
#  ARIMA(2,0,2)(3,0,0)[4]             : AIC=222.310, Time=0.12 sec
#  ARIMA(1,0,0)(3,0,0)[4]             : AIC=242.862, Time=0.06 sec
#  ARIMA(1,0,2)(3,0,0)[4]             : AIC=229.865, Time=0.09 sec
#  ARIMA(3,0,0)(3,0,0)[4]             : AIC=223.710, Time=0.07 sec
#  ARIMA(3,0,2)(3,0,0)[4]             : AIC=inf, Time=0.25 sec
#
# Best model:  ARIMA(2,0,1)(3,0,0)[4]
# Total fit time: 7.839 seconds
# Traverse FAI_Cum equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=358.995, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=374.844, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=363.995, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=355.986, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=373.192, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=369.731, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=357.790, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,2)[4] intercept   : AIC=357.805, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,0)[4] intercept   : AIC=360.922, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,2)[4] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,1)[4] intercept   : AIC=362.143, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,1)[4] intercept   : AIC=357.304, Time=0.04 sec
#  ARIMA(0,1,2)(0,0,1)[4] intercept   : AIC=357.247, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=358.685, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,1)[4] intercept   : AIC=359.246, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,1)[4]             : AIC=358.743, Time=0.02 sec
#
# Best model:  ARIMA(0,1,1)(0,0,1)[4] intercept
# Total fit time: 0.684 seconds
# Traverse Retail_Sales_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=372.145, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=407.720, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=375.635, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=393.997, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=470.680, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,1)[4] intercept   : AIC=372.533, Time=0.08 sec
#  ARIMA(1,0,1)(1,0,0)[4] intercept   : AIC=371.364, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[4] intercept   : AIC=389.315, Time=0.03 sec
#  ARIMA(1,0,1)(2,0,0)[4] intercept   : AIC=372.419, Time=0.12 sec
#  ARIMA(1,0,1)(2,0,1)[4] intercept   : AIC=374.038, Time=0.19 sec
#  ARIMA(0,0,1)(1,0,0)[4] intercept   : AIC=392.766, Time=0.04 sec
#  ARIMA(2,0,1)(1,0,0)[4] intercept   : AIC=371.647, Time=0.12 sec
#  ARIMA(1,0,2)(1,0,0)[4] intercept   : AIC=371.623, Time=0.12 sec
#  ARIMA(0,0,0)(1,0,0)[4] intercept   : AIC=409.719, Time=0.03 sec
#  ARIMA(0,0,2)(1,0,0)[4] intercept   : AIC=387.497, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,0)[4] intercept   : AIC=374.470, Time=0.05 sec
#  ARIMA(2,0,2)(1,0,0)[4] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(1,0,1)(1,0,0)[4]             : AIC=371.387, Time=0.04 sec
#
# Best model:  ARIMA(1,0,1)(1,0,0)[4] intercept
# Total fit time: 1.303 seconds
# Traverse Imports_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=455.407, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=452.318, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=453.826, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=454.021, Time=0.02 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=450.983, Time=0.06 sec
#  ARIMA(1,1,0)(3,0,0)[4] intercept   : AIC=451.907, Time=0.09 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(1,1,0)(3,0,1)[4] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,0)(2,0,0)[4] intercept   : AIC=452.197, Time=0.04 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=452.712, Time=0.07 sec
#  ARIMA(1,1,1)(2,0,0)[4] intercept   : AIC=452.858, Time=0.08 sec
#  ARIMA(0,1,1)(2,0,0)[4] intercept   : AIC=451.021, Time=0.06 sec
#  ARIMA(2,1,1)(2,0,0)[4] intercept   : AIC=453.663, Time=0.14 sec
#  ARIMA(1,1,0)(2,0,0)[4]             : AIC=450.128, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[4]             : AIC=451.109, Time=0.02 sec
#  ARIMA(1,1,0)(3,0,0)[4]             : AIC=451.139, Time=0.04 sec
#  ARIMA(1,1,0)(2,0,1)[4]             : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,0)(1,0,1)[4]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,1,0)(3,0,1)[4]             : AIC=inf, Time=0.21 sec
#  ARIMA(0,1,0)(2,0,0)[4]             : AIC=450.971, Time=0.03 sec
#  ARIMA(2,1,0)(2,0,0)[4]             : AIC=451.988, Time=0.04 sec
#  ARIMA(1,1,1)(2,0,0)[4]             : AIC=452.069, Time=0.05 sec
#  ARIMA(0,1,1)(2,0,0)[4]             : AIC=450.255, Time=0.04 sec
#  ARIMA(2,1,1)(2,0,0)[4]             : AIC=inf, Time=0.19 sec
#
# Best model:  ARIMA(1,1,0)(2,0,0)[4]
# Total fit time: 2.262 seconds
# Traverse Exports_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=454.637, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=441.307, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=452.697, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=445.485, Time=0.02 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=439.286, Time=0.06 sec
#  ARIMA(1,1,0)(3,0,0)[4] intercept   : AIC=437.310, Time=0.07 sec
#  ARIMA(1,1,0)(4,0,0)[4] intercept   : AIC=438.756, Time=0.10 sec
#  ARIMA(1,1,0)(3,0,1)[4] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(1,1,0)(4,0,1)[4] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,1,0)(3,0,0)[4] intercept   : AIC=443.724, Time=0.06 sec
#  ARIMA(2,1,0)(3,0,0)[4] intercept   : AIC=435.101, Time=0.11 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=435.758, Time=0.08 sec
#  ARIMA(2,1,0)(4,0,0)[4] intercept   : AIC=436.988, Time=0.12 sec
#  ARIMA(2,1,0)(3,0,1)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(2,1,0)(4,0,1)[4] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(3,1,0)(3,0,0)[4] intercept   : AIC=436.254, Time=0.10 sec
#  ARIMA(2,1,1)(3,0,0)[4] intercept   : AIC=435.560, Time=0.14 sec
#  ARIMA(1,1,1)(3,0,0)[4] intercept   : AIC=436.978, Time=0.10 sec
#  ARIMA(3,1,1)(3,0,0)[4] intercept   : AIC=437.433, Time=0.26 sec
#  ARIMA(2,1,0)(3,0,0)[4]             : AIC=434.141, Time=0.06 sec
#  ARIMA(2,1,0)(2,0,0)[4]             : AIC=434.947, Time=0.04 sec
#  ARIMA(2,1,0)(4,0,0)[4]             : AIC=436.015, Time=0.07 sec
#  ARIMA(2,1,0)(3,0,1)[4]             : AIC=inf, Time=0.25 sec
#  ARIMA(2,1,0)(2,0,1)[4]             : AIC=inf, Time=0.18 sec
#  ARIMA(2,1,0)(4,0,1)[4]             : AIC=inf, Time=0.32 sec
#  ARIMA(1,1,0)(3,0,0)[4]             : AIC=435.975, Time=0.05 sec
#  ARIMA(3,1,0)(3,0,0)[4]             : AIC=435.026, Time=0.07 sec
#  ARIMA(2,1,1)(3,0,0)[4]             : AIC=434.331, Time=0.09 sec
#  ARIMA(1,1,1)(3,0,0)[4]             : AIC=435.939, Time=0.06 sec
#  ARIMA(3,1,1)(3,0,0)[4]             : AIC=436.101, Time=0.15 sec
#
# Best model:  ARIMA(2,1,0)(3,0,0)[4]
# Total fit time: 4.377 seconds
# Traverse M1 equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=301.867, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=417.967, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=306.607, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=352.157, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=464.530, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,1)[4] intercept   : AIC=301.152, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[4] intercept   : AIC=304.400, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,2)[4] intercept   : AIC=299.601, Time=0.08 sec
#  ARIMA(1,0,1)(1,0,2)[4] intercept   : AIC=300.426, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,3)[4] intercept   : AIC=300.068, Time=0.09 sec
#  ARIMA(1,0,1)(1,0,3)[4] intercept   : AIC=302.054, Time=0.13 sec
#  ARIMA(0,0,1)(0,0,2)[4] intercept   : AIC=354.086, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,2)[4] intercept   : AIC=300.781, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,2)[4] intercept   : AIC=293.991, Time=0.20 sec
#  ARIMA(2,0,1)(0,0,1)[4] intercept   : AIC=292.341, Time=0.13 sec
#  ARIMA(2,0,1)(0,0,0)[4] intercept   : AIC=306.559, Time=0.04 sec
#  ARIMA(2,0,1)(1,0,1)[4] intercept   : AIC=294.300, Time=0.19 sec
#  ARIMA(2,0,1)(1,0,0)[4] intercept   : AIC=307.895, Time=0.07 sec
#  ARIMA(2,0,1)(1,0,2)[4] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(2,0,0)(0,0,1)[4] intercept   : AIC=297.232, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,1)[4] intercept   : AIC=291.036, Time=0.07 sec
#  ARIMA(3,0,1)(0,0,0)[4] intercept   : AIC=297.161, Time=0.04 sec
#  ARIMA(3,0,1)(1,0,1)[4] intercept   : AIC=293.036, Time=0.11 sec
#  ARIMA(3,0,1)(0,0,2)[4] intercept   : AIC=293.033, Time=0.11 sec
#  ARIMA(3,0,1)(1,0,0)[4] intercept   : AIC=294.658, Time=0.08 sec
#  ARIMA(3,0,1)(1,0,2)[4] intercept   : AIC=293.877, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,1)[4] intercept   : AIC=289.768, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[4] intercept   : AIC=295.575, Time=0.03 sec
#  ARIMA(3,0,0)(1,0,1)[4] intercept   : AIC=291.765, Time=0.09 sec
#  ARIMA(3,0,0)(0,0,2)[4] intercept   : AIC=291.735, Time=0.09 sec
#  ARIMA(3,0,0)(1,0,0)[4] intercept   : AIC=293.183, Time=0.05 sec
#  ARIMA(3,0,0)(1,0,2)[4] intercept   : AIC=292.999, Time=0.11 sec
#  ARIMA(3,0,0)(0,0,1)[4]             : AIC=289.757, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[4]             : AIC=296.746, Time=0.07 sec
#  ARIMA(3,0,0)(1,0,1)[4]             : AIC=291.692, Time=0.07 sec
#  ARIMA(3,0,0)(0,0,2)[4]             : AIC=291.459, Time=0.06 sec
#  ARIMA(3,0,0)(1,0,0)[4]             : AIC=294.160, Time=0.04 sec
#  ARIMA(3,0,0)(1,0,2)[4]             : AIC=293.740, Time=0.15 sec
#  ARIMA(2,0,0)(0,0,1)[4]             : AIC=296.385, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,1)[4]             : AIC=291.217, Time=0.07 sec
#  ARIMA(2,0,1)(0,0,1)[4]             : AIC=292.363, Time=0.08 sec
#
# Best model:  ARIMA(3,0,0)(0,0,1)[4]
# Total fit time: 3.227 seconds
# Traverse M2 equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=214.789, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=332.321, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=212.378, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=264.237, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=493.783, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=213.356, Time=0.02 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=210.613, Time=0.10 sec
#  ARIMA(1,0,0)(3,0,0)[4] intercept   : AIC=209.562, Time=0.13 sec
#  ARIMA(1,0,0)(4,0,0)[4] intercept   : AIC=206.944, Time=0.19 sec
#  ARIMA(1,0,0)(5,0,0)[4] intercept   : AIC=208.929, Time=0.22 sec
#  ARIMA(1,0,0)(4,0,1)[4] intercept   : AIC=208.937, Time=0.26 sec
#  ARIMA(1,0,0)(3,0,1)[4] intercept   : AIC=208.783, Time=0.15 sec
#  ARIMA(1,0,0)(5,0,1)[4] intercept   : AIC=210.897, Time=0.38 sec
#  ARIMA(0,0,0)(4,0,0)[4] intercept   : AIC=298.251, Time=0.18 sec
#  ARIMA(2,0,0)(4,0,0)[4] intercept   : AIC=208.929, Time=0.22 sec
#  ARIMA(1,0,1)(4,0,0)[4] intercept   : AIC=208.934, Time=0.20 sec
#  ARIMA(0,0,1)(4,0,0)[4] intercept   : AIC=254.250, Time=0.25 sec
#  ARIMA(2,0,1)(4,0,0)[4] intercept   : AIC=210.877, Time=0.33 sec
#  ARIMA(1,0,0)(4,0,0)[4]             : AIC=inf, Time=0.14 sec
#
# Best model:  ARIMA(1,0,0)(4,0,0)[4] intercept
# Total fit time: 3.023 seconds
# Traverse Loans_RMB equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=169.193, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=303.703, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=219.886, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=509.633, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,1)[4] intercept   : AIC=165.913, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[4] intercept   : AIC=165.201, Time=0.04 sec
#  ARIMA(1,0,1)(1,0,0)[4] intercept   : AIC=165.846, Time=0.11 sec
#  ARIMA(0,0,1)(0,0,0)[4] intercept   : AIC=243.565, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=163.921, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,1)[4] intercept   : AIC=164.167, Time=0.09 sec
#  ARIMA(1,0,0)(1,0,1)[4] intercept   : AIC=167.915, Time=0.16 sec
#  ARIMA(2,0,0)(0,0,0)[4] intercept   : AIC=165.230, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[4] intercept   : AIC=167.199, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,0)[4]             : AIC=inf, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[4] intercept
# Total fit time: 0.968 seconds
# Traverse Social_Financing equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=98.967, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=95.050, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=93.121, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=102.805, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=97.407, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,2)[4] intercept   : AIC=94.778, Time=0.09 sec
#  ARIMA(0,1,1)(1,0,0)[4] intercept   : AIC=96.356, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,2)[4] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,1)[4] intercept   : AIC=92.888, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[4] intercept   : AIC=97.451, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,2)[4] intercept   : AIC=94.512, Time=0.10 sec
#  ARIMA(1,1,1)(1,0,0)[4] intercept   : AIC=96.607, Time=0.05 sec
#  ARIMA(1,1,1)(1,0,2)[4] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=91.629, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=95.806, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=93.184, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=92.781, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,1)[4] intercept   : AIC=94.768, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,1)[4]             : AIC=93.615, Time=0.02 sec
#
# Best model:  ARIMA(1,1,0)(0,0,1)[4] intercept
# Total fit time: 1.875 seconds
# Traverse Manuf_PMI equation...
# Performing stepwise search to minimize aic
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=204.086, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=182.658, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=181.146, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=202.348, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=182.970, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,2)[4] intercept   : AIC=180.271, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,2)[4] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,3)[4] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,1,1)(1,0,3)[4] intercept   : AIC=179.195, Time=0.12 sec
#  ARIMA(0,1,1)(2,0,3)[4] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,1,1)(1,0,4)[4] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,1,1)(0,0,4)[4] intercept   : AIC=177.880, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,5)[4] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,1,1)(1,0,5)[4] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(0,1,0)(0,0,4)[4] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,1,1)(0,0,4)[4] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,2)(0,0,4)[4] intercept   : AIC=177.095, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,3)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,1,2)(1,0,4)[4] intercept   : AIC=178.935, Time=0.34 sec
#  ARIMA(0,1,2)(0,0,5)[4] intercept   : AIC=178.712, Time=0.22 sec
#  ARIMA(0,1,2)(1,0,3)[4] intercept   : AIC=178.681, Time=0.14 sec
#  ARIMA(0,1,2)(1,0,5)[4] intercept   : AIC=180.675, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,4)[4] intercept   : AIC=179.042, Time=0.35 sec
#  ARIMA(0,1,3)(0,0,4)[4] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(1,1,3)(0,0,4)[4] intercept   : AIC=180.581, Time=0.37 sec
#  ARIMA(0,1,2)(0,0,4)[4]             : AIC=175.778, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,3)[4]             : AIC=inf, Time=0.17 sec
#  ARIMA(0,1,2)(1,0,4)[4]             : AIC=177.704, Time=0.19 sec
#  ARIMA(0,1,2)(0,0,5)[4]             : AIC=177.595, Time=0.14 sec
#  ARIMA(0,1,2)(1,0,3)[4]             : AIC=177.297, Time=0.10 sec
#  ARIMA(0,1,2)(1,0,5)[4]             : AIC=179.555, Time=0.21 sec
#  ARIMA(0,1,1)(0,0,4)[4]             : AIC=177.147, Time=0.14 sec
#  ARIMA(1,1,2)(0,0,4)[4]             : AIC=177.777, Time=0.25 sec
#  ARIMA(0,1,3)(0,0,4)[4]             : AIC=177.775, Time=0.17 sec
#  ARIMA(1,1,1)(0,0,4)[4]             : AIC=inf, Time=0.20 sec
#  ARIMA(1,1,3)(0,0,4)[4]             : AIC=179.778, Time=0.19 sec
#
# Best model:  ARIMA(0,1,2)(0,0,4)[4]
# Total fit time: 7.168 seconds
# Traverse Ind_Revenue_Cum equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,0,1)[4]             : AIC=inf, Time=0.12 sec
#  ARIMA(0,2,0)(0,0,0)[4]             : AIC=233.540, Time=0.01 sec
#  ARIMA(1,2,0)(1,0,0)[4]             : AIC=221.146, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,1)[4]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,2,0)(0,0,0)[4]             : AIC=225.413, Time=0.01 sec
#  ARIMA(1,2,0)(2,0,0)[4]             : AIC=219.820, Time=0.04 sec
#  ARIMA(1,2,0)(3,0,0)[4]             : AIC=220.105, Time=0.05 sec
#  ARIMA(1,2,0)(2,0,1)[4]             : AIC=inf, Time=0.13 sec
#  ARIMA(1,2,0)(1,0,1)[4]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,2,0)(3,0,1)[4]             : AIC=inf, Time=0.18 sec
#  ARIMA(0,2,0)(2,0,0)[4]             : AIC=227.971, Time=0.03 sec
#  ARIMA(2,2,0)(2,0,0)[4]             : AIC=216.059, Time=0.04 sec
#  ARIMA(2,2,0)(1,0,0)[4]             : AIC=217.171, Time=0.03 sec
#  ARIMA(2,2,0)(3,0,0)[4]             : AIC=216.754, Time=0.06 sec
#  ARIMA(2,2,0)(2,0,1)[4]             : AIC=inf, Time=0.13 sec
#  ARIMA(2,2,0)(1,0,1)[4]             : AIC=214.307, Time=0.06 sec
#  ARIMA(2,2,0)(0,0,1)[4]             : AIC=212.543, Time=0.03 sec
#  ARIMA(2,2,0)(0,0,0)[4]             : AIC=220.453, Time=0.01 sec
#  ARIMA(2,2,0)(0,0,2)[4]             : AIC=214.319, Time=0.05 sec
#  ARIMA(2,2,0)(1,0,2)[4]             : AIC=inf, Time=0.16 sec
#  ARIMA(1,2,0)(0,0,1)[4]             : AIC=215.745, Time=0.02 sec
#  ARIMA(3,2,0)(0,0,1)[4]             : AIC=inf, Time=0.08 sec
#  ARIMA(2,2,1)(0,0,1)[4]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,2,1)(0,0,1)[4]             : AIC=inf, Time=0.08 sec
#  ARIMA(3,2,1)(0,0,1)[4]             : AIC=inf, Time=0.11 sec
#  ARIMA(2,2,0)(0,0,1)[4] intercept   : AIC=214.543, Time=0.04 sec
#
# Best model:  ARIMA(2,2,0)(0,0,1)[4]
# Total fit time: 1.739 seconds
# Traverse PPIRM_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=382.096, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=286.380, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=384.774, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=289.496, Time=0.01 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=275.113, Time=0.05 sec
#  ARIMA(1,0,0)(3,0,0)[4] intercept   : AIC=275.056, Time=0.07 sec
#  ARIMA(1,0,0)(4,0,0)[4] intercept   : AIC=276.675, Time=0.10 sec
#  ARIMA(1,0,0)(3,0,1)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(1,0,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(1,0,0)(4,0,1)[4] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(3,0,0)[4] intercept   : AIC=372.081, Time=0.06 sec
#  ARIMA(2,0,0)(3,0,0)[4] intercept   : AIC=256.218, Time=0.07 sec
#  ARIMA(2,0,0)(2,0,0)[4] intercept   : AIC=254.616, Time=0.06 sec
#  ARIMA(2,0,0)(1,0,0)[4] intercept   : AIC=269.190, Time=0.03 sec
#  ARIMA(2,0,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(2,0,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(2,0,0)(3,0,1)[4] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(3,0,0)(2,0,0)[4] intercept   : AIC=253.093, Time=0.08 sec
#  ARIMA(3,0,0)(1,0,0)[4] intercept   : AIC=267.879, Time=0.04 sec
#  ARIMA(3,0,0)(3,0,0)[4] intercept   : AIC=254.087, Time=0.08 sec
#  ARIMA(3,0,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(3,0,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(3,0,0)(3,0,1)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(3,0,1)(2,0,0)[4] intercept   : AIC=251.366, Time=0.23 sec
#  ARIMA(3,0,1)(1,0,0)[4] intercept   : AIC=268.033, Time=0.08 sec
#  ARIMA(3,0,1)(3,0,0)[4] intercept   : AIC=252.199, Time=0.32 sec
#  ARIMA(3,0,1)(2,0,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(3,0,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(3,0,1)(3,0,1)[4] intercept   : AIC=253.626, Time=0.32 sec
#  ARIMA(2,0,1)(2,0,0)[4] intercept   : AIC=251.839, Time=0.09 sec
#  ARIMA(3,0,2)(2,0,0)[4] intercept   : AIC=255.100, Time=0.21 sec
#  ARIMA(2,0,2)(2,0,0)[4] intercept   : AIC=253.763, Time=0.10 sec
#  ARIMA(3,0,1)(2,0,0)[4]             : AIC=253.751, Time=0.13 sec
#
# Best model:  ARIMA(3,0,1)(2,0,0)[4] intercept
# Total fit time: 4.946 seconds
# Traverse CGPI_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=349.536, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=257.408, Time=0.13 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=714.266, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=260.903, Time=0.02 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=247.179, Time=0.18 sec
#  ARIMA(1,0,0)(3,0,0)[4] intercept   : AIC=246.580, Time=0.25 sec
#  ARIMA(1,0,0)(4,0,0)[4] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(1,0,0)(3,0,1)[4] intercept   : AIC=246.084, Time=0.31 sec
#  ARIMA(1,0,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(1,0,0)(4,0,1)[4] intercept   : AIC=243.618, Time=0.38 sec
#  ARIMA(1,0,0)(5,0,1)[4] intercept   : AIC=241.191, Time=0.47 sec
#  ARIMA(1,0,0)(5,0,0)[4] intercept   : AIC=247.044, Time=0.39 sec
#  ARIMA(1,0,0)(5,0,2)[4] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(1,0,0)(4,0,2)[4] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(5,0,1)[4] intercept   : AIC=337.198, Time=0.38 sec
#  ARIMA(2,0,0)(5,0,1)[4] intercept   : AIC=232.861, Time=0.45 sec
#  ARIMA(2,0,0)(4,0,1)[4] intercept   : AIC=239.811, Time=0.45 sec
#  ARIMA(2,0,0)(5,0,0)[4] intercept   : AIC=231.875, Time=0.41 sec
#  ARIMA(2,0,0)(4,0,0)[4] intercept   : AIC=246.516, Time=0.37 sec
#  ARIMA(3,0,0)(5,0,0)[4] intercept   : AIC=233.266, Time=0.50 sec
#  ARIMA(2,0,1)(5,0,0)[4] intercept   : AIC=231.539, Time=0.42 sec
#  ARIMA(2,0,1)(4,0,0)[4] intercept   : AIC=240.252, Time=0.40 sec
#  ARIMA(2,0,1)(5,0,1)[4] intercept   : AIC=233.158, Time=0.47 sec
#  ARIMA(2,0,1)(4,0,1)[4] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(1,0,1)(5,0,0)[4] intercept   : AIC=234.556, Time=0.37 sec
#  ARIMA(3,0,1)(5,0,0)[4] intercept   : AIC=235.036, Time=0.53 sec
#  ARIMA(2,0,2)(5,0,0)[4] intercept   : AIC=235.473, Time=0.47 sec
#  ARIMA(1,0,2)(5,0,0)[4] intercept   : AIC=236.276, Time=0.43 sec
#  ARIMA(3,0,2)(5,0,0)[4] intercept   : AIC=232.586, Time=0.65 sec
#  ARIMA(2,0,1)(5,0,0)[4]             : AIC=inf, Time=0.33 sec
#
# Best model:  ARIMA(2,0,1)(5,0,0)[4] intercept
# Total fit time: 10.865 seconds
# Traverse 70_Cities_Price_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=163.778, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=213.369, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=164.718, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=177.286, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=214.034, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,1)[4] intercept   : AIC=161.887, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[4] intercept   : AIC=181.357, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,2)[4] intercept   : AIC=163.823, Time=0.08 sec
#  ARIMA(1,1,1)(1,0,0)[4] intercept   : AIC=166.511, Time=0.04 sec
#  ARIMA(1,1,1)(1,0,2)[4] intercept   : AIC=165.748, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=159.887, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=180.145, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=161.778, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=161.823, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=163.748, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,1)[4] intercept   : AIC=204.183, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=161.886, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,1)[4]             : AIC=159.704, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[4]             : AIC=178.985, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,1)[4]             : AIC=161.399, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,2)[4]             : AIC=161.469, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[4]             : AIC=163.940, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,2)[4]             : AIC=163.392, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,1)[4]             : AIC=207.156, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,1)[4]             : AIC=161.704, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,1)[4]             : AIC=161.704, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[4]             : AIC=178.916, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,1)[4]             : AIC=163.533, Time=0.07 sec
#
# Best model:  ARIMA(1,1,0)(0,0,1)[4]
# Total fit time: 1.553 seconds
# Traverse Power_Gen_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=353.576, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=331.916, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=339.076, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=398.605, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=333.604, Time=0.02 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=333.696, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,1)[4] intercept   : AIC=327.849, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,2)[4] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(1,0,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,1)[4] intercept   : AIC=355.366, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(2,0,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,1)[4]             : AIC=331.448, Time=0.03 sec
#
# Best model:  ARIMA(1,0,0)(0,0,1)[4] intercept
# Total fit time: 1.139 seconds
# Traverse Freight_Mth equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=353.801, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=360.323, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=352.651, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=356.064, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=398.673, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=356.027, Time=0.01 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=351.432, Time=0.05 sec
#  ARIMA(1,0,0)(3,0,0)[4] intercept   : AIC=353.387, Time=0.08 sec
#  ARIMA(1,0,0)(2,0,1)[4] intercept   : AIC=353.405, Time=0.08 sec
#  ARIMA(1,0,0)(1,0,1)[4] intercept   : AIC=352.345, Time=0.08 sec
#  ARIMA(1,0,0)(3,0,1)[4] intercept   : AIC=354.091, Time=0.25 sec
#  ARIMA(0,0,0)(2,0,0)[4] intercept   : AIC=358.170, Time=0.05 sec
#  ARIMA(2,0,0)(2,0,0)[4] intercept   : AIC=353.169, Time=0.07 sec
#  ARIMA(1,0,1)(2,0,0)[4] intercept   : AIC=353.131, Time=0.08 sec
#  ARIMA(0,0,1)(2,0,0)[4] intercept   : AIC=353.188, Time=0.05 sec
#  ARIMA(2,0,1)(2,0,0)[4] intercept   : AIC=355.119, Time=0.13 sec
#  ARIMA(1,0,0)(2,0,0)[4]             : AIC=360.678, Time=0.03 sec
#
# Best model:  ARIMA(1,0,0)(2,0,0)[4] intercept
# Total fit time: 1.135 seconds
# Traverse Urban_Income_Cum equation...
# Performing stepwise search to minimize aic
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=216.093, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=305.172, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=216.366, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=255.481, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=425.812, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,1)[4] intercept   : AIC=216.241, Time=0.06 sec
#  ARIMA(1,0,1)(1,0,0)[4] intercept   : AIC=218.267, Time=0.08 sec
#  ARIMA(1,0,1)(2,0,1)[4] intercept   : AIC=217.813, Time=0.14 sec
#  ARIMA(1,0,1)(1,0,2)[4] intercept   : AIC=213.777, Time=0.19 sec
#  ARIMA(1,0,1)(0,0,2)[4] intercept   : AIC=215.561, Time=0.10 sec
#  ARIMA(1,0,1)(2,0,2)[4] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(1,0,1)(1,0,3)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(1,0,1)(0,0,3)[4] intercept   : AIC=217.089, Time=0.11 sec
#  ARIMA(1,0,1)(2,0,3)[4] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,1)(1,0,2)[4] intercept   : AIC=258.400, Time=0.17 sec
#  ARIMA(1,0,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(2,0,1)(1,0,2)[4] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,0,2)(1,0,2)[4] intercept   : AIC=215.832, Time=0.22 sec
#  ARIMA(0,0,0)(1,0,2)[4] intercept   : AIC=307.243, Time=0.14 sec
#  ARIMA(0,0,2)(1,0,2)[4] intercept   : AIC=247.881, Time=0.23 sec
#  ARIMA(2,0,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(2,0,2)(1,0,2)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(1,0,1)(1,0,2)[4]             : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(1,0,1)(1,0,2)[4] intercept
# Total fit time: 3.360 seconds
# Traverse Urban_Exp_Cum equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=301.256, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=358.039, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=299.443, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=322.134, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=425.565, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=321.063, Time=0.02 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=299.678, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,1)[4] intercept   : AIC=299.295, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,1)[4] intercept   : AIC=299.863, Time=0.04 sec
#  ARIMA(1,0,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(1,0,0)(1,0,2)[4] intercept   : AIC=301.198, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,2)[4] intercept   : AIC=300.097, Time=0.05 sec
#  ARIMA(1,0,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,0)(1,0,1)[4] intercept   : AIC=355.101, Time=0.06 sec
#  ARIMA(2,0,0)(1,0,1)[4] intercept   : AIC=301.254, Time=0.07 sec
#  ARIMA(0,0,1)(1,0,1)[4] intercept   : AIC=321.631, Time=0.07 sec
#  ARIMA(2,0,1)(1,0,1)[4] intercept   : AIC=302.359, Time=0.12 sec
#  ARIMA(1,0,0)(1,0,1)[4]             : AIC=302.651, Time=0.05 sec
#
# Best model:  ARIMA(1,0,0)(1,0,1)[4] intercept
# Total fit time: 1.196 seconds
# Traverse Nat_Housing_Index equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,0,1)[4]             : AIC=inf, Time=0.11 sec
#  ARIMA(0,2,0)(0,0,0)[4]             : AIC=229.790, Time=0.01 sec
#  ARIMA(1,2,0)(1,0,0)[4]             : AIC=220.600, Time=0.02 sec
#  ARIMA(0,2,1)(0,0,1)[4]             : AIC=208.389, Time=0.02 sec
#  ARIMA(0,2,1)(0,0,0)[4]             : AIC=207.124, Time=0.01 sec
#  ARIMA(0,2,1)(1,0,0)[4]             : AIC=208.229, Time=0.02 sec
#  ARIMA(0,2,1)(1,0,1)[4]             : AIC=210.140, Time=0.04 sec
#  ARIMA(1,2,1)(0,0,0)[4]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,2,2)(0,0,0)[4]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,2,0)(0,0,0)[4]             : AIC=219.239, Time=0.01 sec
#  ARIMA(1,2,2)(0,0,0)[4]             : AIC=inf, Time=0.10 sec
#  ARIMA(0,2,1)(0,0,0)[4] intercept   : AIC=209.032, Time=0.03 sec
#
# Best model:  ARIMA(0,2,1)(0,0,0)[4]
# Total fit time: 0.484 seconds
# Traverse Macro_Eco_Index equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=339.641, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=285.982, Time=0.15 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=289.693, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=700.280, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=295.965, Time=0.02 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=282.514, Time=0.18 sec
#  ARIMA(1,0,0)(3,0,0)[4] intercept   : AIC=283.554, Time=0.25 sec
#  ARIMA(1,0,0)(2,0,1)[4] intercept   : AIC=289.933, Time=0.28 sec
#  ARIMA(1,0,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(1,0,0)(3,0,1)[4] intercept   : AIC=282.178, Time=0.25 sec
#  ARIMA(1,0,0)(4,0,1)[4] intercept   : AIC=285.026, Time=0.32 sec
#  ARIMA(1,0,0)(3,0,2)[4] intercept   : AIC=283.917, Time=0.27 sec
#  ARIMA(1,0,0)(2,0,2)[4] intercept   : AIC=281.978, Time=0.15 sec
#  ARIMA(1,0,0)(1,0,2)[4] intercept   : AIC=280.102, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,2)[4] intercept   : AIC=278.139, Time=0.14 sec
#  ARIMA(1,0,0)(0,0,1)[4] intercept   : AIC=276.174, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,1)[4] intercept   : AIC=272.943, Time=0.12 sec
#  ARIMA(2,0,0)(0,0,0)[4] intercept   : AIC=284.127, Time=0.03 sec
#  ARIMA(2,0,0)(1,0,1)[4] intercept   : AIC=294.164, Time=0.19 sec
#  ARIMA(2,0,0)(0,0,2)[4] intercept   : AIC=274.419, Time=0.19 sec
#  ARIMA(2,0,0)(1,0,0)[4] intercept   : AIC=279.304, Time=0.14 sec
#  ARIMA(2,0,0)(1,0,2)[4] intercept   : AIC=275.750, Time=0.21 sec
#  ARIMA(3,0,0)(0,0,1)[4] intercept   : AIC=277.155, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,1)[4] intercept   : AIC=274.447, Time=0.15 sec
#  ARIMA(1,0,1)(0,0,1)[4] intercept   : AIC=272.144, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[4] intercept   : AIC=284.696, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,2)[4] intercept   : AIC=273.847, Time=0.10 sec
#  ARIMA(1,0,1)(1,0,0)[4] intercept   : AIC=280.127, Time=0.16 sec
#  ARIMA(1,0,1)(1,0,2)[4] intercept   : AIC=275.865, Time=0.20 sec
#  ARIMA(1,0,2)(0,0,1)[4] intercept   : AIC=274.043, Time=0.10 sec
#  ARIMA(0,0,2)(0,0,1)[4] intercept   : AIC=275.691, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,1)[4] intercept   : AIC=276.667, Time=0.15 sec
#  ARIMA(1,0,1)(0,0,1)[4]             : AIC=286.790, Time=0.05 sec
#
# Best model:  ARIMA(1,0,1)(0,0,1)[4] intercept
# Total fit time: 4.729 seconds
# Traverse Housing_Sales_Cum equation...
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=505.940, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=545.480, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=503.362, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=519.708, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=554.338, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=514.975, Time=0.02 sec
#  ARIMA(1,0,0)(2,0,0)[4] intercept   : AIC=504.064, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,1)[4] intercept   : AIC=504.168, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[4] intercept   : AIC=503.411, Time=0.04 sec
#  ARIMA(1,0,0)(2,0,1)[4] intercept   : AIC=505.728, Time=0.14 sec
#  ARIMA(0,0,0)(1,0,0)[4] intercept   : AIC=544.575, Time=0.03 sec
#  ARIMA(2,0,0)(1,0,0)[4] intercept   : AIC=505.269, Time=0.06 sec
#  ARIMA(1,0,1)(1,0,0)[4] intercept   : AIC=505.284, Time=0.06 sec
#  ARIMA(0,0,1)(1,0,0)[4] intercept   : AIC=519.492, Time=0.04 sec
#  ARIMA(2,0,1)(1,0,0)[4] intercept   : AIC=507.230, Time=0.08 sec
#  ARIMA(1,0,0)(1,0,0)[4]             : AIC=503.585, Time=0.03 sec
#
# Best model:  ARIMA(1,0,0)(1,0,0)[4] intercept
# Total fit time: 0.789 seconds
# The prediction process took a total of 1.18 minutes.
