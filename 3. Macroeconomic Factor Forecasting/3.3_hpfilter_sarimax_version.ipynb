# %% [markdown]
# *https://github.com/Aubrey-Bermuda-CA/IFRS9-MODELING-CHINA*

# %% [markdown]
# *3.3 Function description: Read macro historical data and external prediction data, use HP filter to filter the data, and use SAR IMAX to predict macro data. This version offers more customization details.*

# %%
import re
import time
import itertools
import numpy as np
import pandas as pd
import pmdarima as pm
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.statespace.sarimax import SARIMAXResults

# %%
# set date range
start_date = '2010-03-31'
history_date = '2024-09-30'
forecast_date = '2026-09-30'
date_index = pd.date_range(start=start_date, end=forecast_date, freq='Q')

# read macro data
macro_his_data = pd.read_csv(f'./macrofactor_historical_data.csv', index_col=[0], parse_dates=[0])
macro_fc_data = pd.read_csv(f'./macrofactor_forecast_data.csv', index_col=[0], parse_dates=[0])

# combine data
macro_data = macro_his_data.combine_first(macro_fc_data)

# Missing values ​​can be handled using interpolation. There are several methods to choose from:
# 'linear', 'nearest', 'zero', 'slinear', 'quadratic', 'cubic', 'barycentric', 'polynomial', 
# 'krogh', 'piecewise_polynomial', 'spline', 'pchip', 'akima', 'cubicspline'
# macro_data = macro_data.interpolate(method='spline')

macro_data
# Out:
#             GDP_Const_Qtr  Ind_Pro_Mth  CPI_Mth  Core_CPI_Mth  PPI_Mth  \
# date
# 2010-03-31          12.20         18.1  102.400           NaN     5.91
# 2010-06-30          10.80         13.7  102.900           NaN     6.41
# 2010-09-30           9.90         13.3  103.600           NaN     4.33
# 2010-12-31           9.90         13.5  104.600           NaN     5.93
# 2011-03-31          10.20         14.8  105.383           NaN     7.31
# ...                   ...          ...      ...           ...      ...
# 2024-09-30           4.60          5.4  100.400           0.1    -2.80
# 2024-12-31           4.85          NaN    1.800           0.7    -2.20
# 2025-03-31           4.00          NaN      NaN           NaN      NaN
# 2025-06-30           4.55          NaN      NaN           NaN      NaN
# 2025-09-30           4.20          NaN      NaN           NaN      NaN
#
#             FAI_Cum  Retail_Sales_Mth  Imports_Mth  Exports_Mth     M1  ...  \
# date                                                                    ...
# 2010-03-31     26.4             18.00        66.27        24.21  29.94  ...
# 2010-06-30     25.5             18.30        33.87        43.87  24.56  ...
# 2010-09-30     24.5             18.84        24.38        25.08  20.87  ...
# 2010-12-31     24.5             19.10        25.94        17.87  21.19  ...
# 2011-03-31     25.0             17.40        27.50        35.76  15.00  ...
# ...             ...               ...          ...          ...    ...  ...
# 2024-09-30      3.4              3.20         0.30         2.40  -7.40  ...
# 2024-12-31      3.0              6.40        11.00          NaN  -6.50  ...
# 2025-03-31      3.6               NaN          NaN          NaN    NaN  ...
# 2025-06-30      3.9               NaN          NaN          NaN    NaN  ...
# 2025-09-30      4.0               NaN          NaN          NaN    NaN  ...
#
#             PPIRM_Mth  CGPI_Mth  70_Cities_Price_Mth  Power_Gen_Mth  \
# date
# 2010-03-31      11.46     105.6                  9.5           17.6
# 2010-06-30      10.80     106.6                  7.7           11.4
# 2010-09-30       7.10     106.1                  6.2            8.1
# 2010-12-31       9.47     107.9                  5.0            5.1
# 2011-03-31      10.53     109.3                  3.7           14.8
# ...               ...       ...                  ...            ...
# 2024-09-30      -2.20      98.3                 -9.0            6.0
# 2024-12-31        NaN       NaN                  NaN            NaN
# 2025-03-31        NaN       NaN                  NaN            NaN
# 2025-06-30        NaN       NaN                  NaN            NaN
# 2025-09-30        NaN       NaN                  NaN            NaN
#
#             Freight_Mth  Urban_Income_Cum  Urban_Exp_Cum  Nat_Housing_Index  \
# date
# 2010-03-31    15.800000               9.8          11.01             105.89
# 2010-06-30    12.300000              10.2           9.89             105.06
# 2010-09-30    11.900000              10.5           9.32             103.52
# 2010-12-31     0.310000              11.3           9.84             101.79
# 2011-03-31    14.300000              12.3          10.69             102.98
# ...                 ...               ...            ...                ...
# 2024-09-30     2.315156               4.5           5.00              92.40
# 2024-12-31          NaN               NaN            NaN                NaN
# 2025-03-31          NaN               NaN            NaN                NaN
# 2025-06-30          NaN               NaN            NaN                NaN
# 2025-09-30          NaN               NaN            NaN                NaN
#
#             Macro_Eco_Index  Housing_Sales_Cum
# date
# 2010-03-31            104.0               57.7
# 2010-06-30            102.6               25.4
# 2010-09-30            101.9               15.9
# 2010-12-31            103.6               18.3
# 2011-03-31            102.5               27.3
# ...                     ...                ...
# 2024-09-30              NaN              -22.7
# 2024-12-31              NaN                NaN
# 2025-03-31              NaN                NaN
# 2025-06-30              NaN                NaN
# 2025-09-30              NaN                NaN
#
# [63 rows x 25 columns]

# %%
# The method used here comes from this article ：https://www.ecb.europa.eu/pub/pdf/scpwps/ecbwp499.pdf. 
# This is just a simple attempt, not a reproduction of the article.
# As concluded in the article, hpfilter obtain more stable predictive values.

# Use Hodrick-Prescott filter to separate trend terms and periodic terms
macro_data_fitted = pd.DataFrame(index=macro_data.index)

for column in macro_data:
    y = macro_data[column].dropna()
    cycle, trend = sm.tsa.filters.hpfilter(y)
    try:
        result = STL(cycle).fit()
        seasonal = result.seasonal
        seasonal = seasonal.rename(column)
        seasonal_smooth = seasonal[abs(seasonal - seasonal.mean()) <= 2.576 * seasonal.std()] # 99% confidence level value
        fitted = trend.add(seasonal_smooth, fill_value=0)
    except:
        seasonal = pd.DataFrame(index=trend.index, columns=[column])
        cycle_smooth = cycle[abs(cycle - cycle.mean()) <= 2.576 * cycle.std()]
        fitted = trend.add(cycle_smooth, fill_value=0)
    
    # # Create a graphics object
    # fig, ax1 = plt.subplots(figsize=(10, 5))
    # ax1.plot(y.index, y, label=column, color='g')
    # ax1.plot(y.index, fitted, label='Fitted', color='b')
    # ax1.set_xlabel('Date')
    # ax1.set_ylabel('Value and Fitted')
    # ax1.legend(loc='upper left')

    # # Create a secondary axis
    # ax2 = ax1.twinx() 
    # ax2.plot(y.index, seasonal, label='Seasonal', color='gray', linestyle='--')
    # ax2.set_ylabel('Seasonal', color='k')
    # ax2.legend(loc='upper right')
    # plt.title('Original, Seasonal and Fitted (HP filter)')
    # plt.show()

    macro_data_fitted = macro_data_fitted.merge(fitted.rename(column), left_index=True, right_index=True, how='left')

macro_data_fitted.to_csv(f'./3.3_macro_data_fitted.csv')

# %%
# to avoid Maximum Likelihood convergence warning
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='statsmodels')

# macrofactor forecast with sarimax
df = macro_data_fitted
# Set the frequency
df = df.asfreq('Q-DEC')
predict_data = pd.DataFrame(index=date_index)
print(f'macrofoctor_list：{df.columns.values}')

# timer
start_t = time.perf_counter()

# loss function, You can customize your own loss function
def func_calc_rmse(y, y_pred):
    try:
        res_rmse = np.sqrt(np.mean((y[-16:-4] - y_pred[-16:-4]) ** 2))
    except:
        res_rmse = np.inf
    return res_rmse

# Define parameter range
p_values = range(2, 5)
q_values = range(2, 5)
P_values = range(0, 2)
Q_values = range(0, 2)

# fit model
for column in df:
    y = df[column].dropna()
    print(f"\n Traversing the SARIMA equations of {y.name} ...")
    # seasonal data use 4
    m = 4
    # calc d and D firt to save time
    d = pm.arima.ndiffs(y, alpha=0.05, test='adf', max_d=2)
    D = 0 # Differences in seasonal items can cause abnormal fluctuations in data
    
    # Initialize optimal parameters and maximum loss function
    best_rmse = float('inf')
    best_params = None
    
    # Traversing
    for p, q, P, Q in itertools.product(p_values, q_values, P_values, Q_values):
        try:
            time_dur0 = time.perf_counter()
            # fit sarimax model
            model = SARIMAX(y, order=(p, d, q), seasonal_order=(P, D, Q, m), enforce_stationarity=False, enforce_invertibility=False)
            results = model.fit(disp=False)
            
            # results summary
            res_summary = results.summary().as_text()
            
            # Hypothesis testing can also be customized as needed
            # Ljung-Box(Q) test: used to test whether the residual is white noise (randomness). 
            # if p_value > 0.01, the null hypothesis is accepted, indicating that the residuals are white noise.
            Ljung_Box_match = re.search(r'Prob\(Q\):\s+([\d.]+)', res_summary)
            LB_p = float(Ljung_Box_match.group(1)) if Ljung_Box_match else None
            
            # Heteroskedasticity test: Indicates whether the variance of the error term changes over time. 
            # If p-value > 0.01, the null hypothesis is accepted, the variance of the error term is independent 
            # of time and there is no heteroskedasticity.
            # Heteroskedasticity_match = re.search(r'Prob\(H\) \(two-sided\):\s+([\d.]+)', res_summary)
            # Het_p = float(Heteroskedasticity_match.group(1)) if Heteroskedasticity_match else None

            # calculate loss function
            # mse = results.mse
            y_pred = results.predict()
            rmse = func_calc_rmse(y, y_pred)
            time_dur = time.perf_counter() - time_dur0
            print(f'({p},{d},{q})({P},{D},{Q})[{m}],	Ljung-Box(Q) = {LB_p:.2f},	RMSE = {rmse:.4f},	time = {time_dur:.2f}s')
            
            # Update optimal parameters
            if (LB_p >= 0.01) & (rmse < best_rmse):
                best_rmse = rmse
                best_params = f'({p},{d},{q})({P},{D},{Q})[{m}]'
                pr_in = y_pred
                pr_out = results.forecast(steps=15)
                
        except Exception as e:
            # print("An error occurred:", e)
            continue
    
    pr = pd.DataFrame({column:pd.concat([pr_in, pr_out])})
    print(f'Best RMSE:  {best_rmse:.4f}')
    print(f'{y.name} : Best parameters : {best_params}')
    predict_data = predict_data.merge(pr, left_index=True, right_index=True, how='left')

# Output prediction results
predict_data = macro_data.combine_first(predict_data) # This does not change the value of historical data
# predict_data = macro_data_fitted.combine_first(predict_data) # If you want to use filtered historical values
predict_data.to_csv(f'./3.3_predict_data.csv')

dur = (time.perf_counter() - start_t) / 60
print(f'The prediction process took a total of {dur:,.2f} minutes.')
# Out:
# macrofoctor_list：['GDP_Const_Qtr' 'Ind_Pro_Mth' 'CPI_Mth' 'Core_CPI_Mth' 'PPI_Mth'
#  'FAI_Cum' 'Retail_Sales_Mth' 'Imports_Mth' 'Exports_Mth' 'M1' 'M2'
#  'Loans_RMB' 'Social_Financing' 'Manuf_PMI' 'Ind_Revenue_Cum' 'PPIRM_Mth'
#  'CGPI_Mth' '70_Cities_Price_Mth' 'Power_Gen_Mth' 'Freight_Mth'
#  'Urban_Income_Cum' 'Urban_Exp_Cum' 'Nat_Housing_Index' 'Macro_Eco_Index'
#  'Housing_Sales_Cum']
#
#  Traversing the SARIMA equations of GDP_Const_Qtr ...
# (2,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.09,	RMSE = 0.5459,	time = 0.06s
# (2,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.39,	RMSE = 0.5173,	time = 0.07s
# (2,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.67,	RMSE = 0.4893,	time = 0.04s
# (2,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.80,	RMSE = 0.4707,	time = 0.07s
# (2,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.4863,	time = 0.08s
# (2,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.4649,	time = 0.15s
# (2,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.68,	RMSE = 0.4927,	time = 0.06s
# (2,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.44,	RMSE = 0.4492,	time = 0.12s
# (2,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.38,	RMSE = 0.4747,	time = 0.06s
# (2,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.4671,	time = 0.10s
# (3,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.17,	RMSE = 0.4728,	time = 0.03s
# (3,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.36,	RMSE = 0.4909,	time = 0.05s
# (3,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.64,	RMSE = 0.4646,	time = 0.07s
# (3,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.4555,	time = 0.08s
# (3,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.20,	RMSE = 0.4427,	time = 0.05s
# (3,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.22,	RMSE = 0.4763,	time = 0.07s
# (3,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.4664,	time = 0.12s
# (3,1,3)(1,0,1)[4],	Ljung-Box(Q) = 1.00,	RMSE = 0.4545,	time = 0.11s
# (3,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.15,	RMSE = 0.4586,	time = 0.05s
# (3,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.60,	RMSE = 0.4651,	time = 0.10s
# (4,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.4514,	time = 0.08s
# (4,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.4487,	time = 0.11s
# (4,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.4511,	time = 0.09s
# (4,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.4478,	time = 0.12s
# (4,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.4489,	time = 0.10s
# Best RMSE:  0.4427
# GDP_Const_Qtr : Best parameters : (3,1,3)(0,0,0)[4]
#
#  Traversing the SARIMA equations of Ind_Pro_Mth ...
# (2,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.75,	RMSE = 0.4088,	time = 0.04s
# (2,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.66,	RMSE = 0.2157,	time = 0.04s
# (2,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.75,	RMSE = 0.1809,	time = 0.05s
# (2,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.59,	RMSE = 0.1741,	time = 0.08s
# (2,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.2810,	time = 0.07s
# (2,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.1737,	time = 0.08s
# (2,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.1708,	time = 0.09s
# (2,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.80,	RMSE = 0.1612,	time = 0.12s
# (2,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.70,	RMSE = 0.2002,	time = 0.06s
# (2,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.41,	RMSE = 0.1429,	time = 0.08s
# (3,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.56,	RMSE = 0.2741,	time = 0.08s
# (3,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.1671,	time = 0.09s
# (3,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.1332,	time = 0.09s
# (3,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.2031,	time = 0.07s
# (3,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.2616,	time = 0.09s
# (3,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.60,	RMSE = 0.2054,	time = 0.10s
# (3,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.1672,	time = 0.10s
# (3,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.1879,	time = 0.12s
# (3,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.83,	RMSE = 0.2094,	time = 0.06s
# (3,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.1379,	time = 0.11s
# (4,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.2742,	time = 0.06s
# (4,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.49,	RMSE = 0.1942,	time = 0.11s
# (4,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.71,	RMSE = 0.2736,	time = 0.08s
# (4,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.1768,	time = 0.11s
# (4,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.68,	RMSE = 0.1702,	time = 0.11s
# Best RMSE:  0.1332
# Ind_Pro_Mth : Best parameters : (3,0,2)(1,0,0)[4]
#
#  Traversing the SARIMA equations of CPI_Mth ...
# (2,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.36,	RMSE = 5.7365,	time = 0.03s
# (2,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.51,	RMSE = 5.3459,	time = 0.03s
# (2,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.81,	RMSE = 4.6865,	time = 0.04s
# (2,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.84,	RMSE = 4.6422,	time = 0.06s
# (2,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.09,	RMSE = 5.3034,	time = 0.03s
# (2,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.18,	RMSE = 5.0186,	time = 0.06s
# (2,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.68,	RMSE = 4.7910,	time = 0.04s
# (2,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.75,	RMSE = 4.7542,	time = 0.08s
# (2,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.99,	RMSE = 4.4766,	time = 0.03s
# (2,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.79,	RMSE = 4.5621,	time = 0.05s
# (3,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.51,	RMSE = 4.8509,	time = 0.05s
# (3,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.50,	RMSE = 4.8974,	time = 0.05s
# (3,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.51,	RMSE = 4.9065,	time = 0.05s
# (3,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.51,	RMSE = 4.9068,	time = 0.06s
# (3,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.69,	RMSE = 4.7728,	time = 0.04s
# (3,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.67,	RMSE = 4.8173,	time = 0.06s
# (3,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.69,	RMSE = 4.7718,	time = 0.07s
# (3,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.67,	RMSE = 4.8379,	time = 0.09s
# (3,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.09,	RMSE = 4.7008,	time = 0.05s
# (3,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.09,	RMSE = 4.6979,	time = 0.11s
# (4,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.80,	RMSE = 4.7527,	time = 0.04s
# (4,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.77,	RMSE = 4.7880,	time = 0.06s
# (4,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.84,	RMSE = 4.7961,	time = 0.09s
# (4,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.82,	RMSE = 4.7958,	time = 0.13s
# (4,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 4.6410,	time = 0.07s
# Best RMSE:  4.4766
# CPI_Mth : Best parameters : (2,1,4)(0,0,0)[4]
#
#  Traversing the SARIMA equations of Core_CPI_Mth ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.44,	RMSE = 0.0680,	time = 0.06s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.63,	RMSE = 0.0468,	time = 0.09s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.42,	RMSE = 0.0444,	time = 0.08s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.75,	RMSE = 0.0441,	time = 0.10s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.69,	RMSE = 0.0535,	time = 0.07s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.0416,	time = 0.09s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.54,	RMSE = 0.0462,	time = 0.09s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.81,	RMSE = 0.0433,	time = 0.12s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.32,	RMSE = 0.0512,	time = 0.08s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.67,	RMSE = 0.0500,	time = 0.09s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.58,	RMSE = 0.0564,	time = 0.07s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.52,	RMSE = 0.0434,	time = 0.10s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.0461,	time = 0.09s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.48,	RMSE = 0.0375,	time = 0.13s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.84,	RMSE = 0.0432,	time = 0.08s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.47,	RMSE = 0.0376,	time = 0.10s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.0386,	time = 0.12s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.42,	RMSE = 0.0441,	time = 0.11s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.57,	RMSE = 0.0412,	time = 0.08s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.58,	RMSE = 0.0386,	time = 0.12s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.61,	RMSE = 0.0559,	time = 0.07s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.0386,	time = 0.10s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.30,	RMSE = 0.0443,	time = 0.08s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.0380,	time = 0.12s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.0418,	time = 0.08s
# Best RMSE:  0.0375
# Core_CPI_Mth : Best parameters : (3,2,2)(1,0,1)[4]
#
#  Traversing the SARIMA equations of PPI_Mth ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.85,	RMSE = 0.1642,	time = 0.03s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1216,	time = 0.06s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.55,	RMSE = 0.1458,	time = 0.04s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.1097,	time = 0.08s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.1636,	time = 0.04s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.65,	RMSE = 0.1173,	time = 0.06s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.1442,	time = 0.05s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.81,	RMSE = 0.1101,	time = 0.10s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.55,	RMSE = 0.1793,	time = 0.05s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.30,	RMSE = 0.1390,	time = 0.07s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.37,	RMSE = 0.1991,	time = 0.04s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.1250,	time = 0.07s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 1.00,	RMSE = 0.1559,	time = 0.08s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1136,	time = 0.09s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.15,	RMSE = 0.1575,	time = 0.05s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.76,	RMSE = 0.1329,	time = 0.08s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.67,	RMSE = 0.1443,	time = 0.06s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.58,	RMSE = 0.1184,	time = 0.13s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.71,	RMSE = 0.1309,	time = 0.06s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.85,	RMSE = 0.1278,	time = 0.09s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.05,	RMSE = 5.5128,	time = 0.12s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.90,	RMSE = 7.1847,	time = 0.06s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.1585,	time = 0.09s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.97,	RMSE = 0.1171,	time = 0.12s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.67,	RMSE = 0.1368,	time = 0.08s
# Best RMSE:  0.1097
# PPI_Mth : Best parameters : (2,2,2)(1,0,1)[4]
#
#  Traversing the SARIMA equations of FAI_Cum ...
# (2,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.74,	RMSE = 0.8237,	time = 0.06s
# (2,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.84,	RMSE = 0.5665,	time = 0.08s
# (2,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.4417,	time = 0.07s
# (2,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.97,	RMSE = 0.5277,	time = 0.09s
# (2,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.71,	RMSE = 0.8169,	time = 0.08s
# (2,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.5591,	time = 0.12s
# (2,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.83,	RMSE = 0.5398,	time = 0.08s
# (2,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.83,	RMSE = 0.5708,	time = 0.13s
# (2,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.29,	RMSE = 0.5569,	time = 0.04s
# (2,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.66,	RMSE = 0.5978,	time = 0.05s
# (3,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.32,	RMSE = 0.6889,	time = 0.06s
# (3,1,2)(0,0,1)[4],	Ljung-Box(Q) = 1.00,	RMSE = 0.5667,	time = 0.09s
# (3,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.70,	RMSE = 0.4742,	time = 0.09s
# (3,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.5656,	time = 0.12s
# (3,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.53,	RMSE = 0.6602,	time = 0.10s
# (3,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.5609,	time = 0.14s
# (3,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.68,	RMSE = 0.5515,	time = 0.11s
# (3,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.5363,	time = 0.11s
# (3,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.36,	RMSE = 0.6444,	time = 0.07s
# (3,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.66,	RMSE = 0.5967,	time = 0.08s
# (4,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.4748,	time = 0.05s
# (4,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.93,	RMSE = 0.5555,	time = 0.07s
# (4,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.6638,	time = 0.09s
# (4,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.93,	RMSE = 0.5551,	time = 0.12s
# (4,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.33,	RMSE = 0.6065,	time = 0.05s
# Best RMSE:  0.4417
# FAI_Cum : Best parameters : (2,1,2)(1,0,0)[4]
#
#  Traversing the SARIMA equations of Retail_Sales_Mth ...
# (2,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.37,	RMSE = 1.3349,	time = 0.03s
# (2,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.07,	RMSE = 1.1713,	time = 0.08s
# (2,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.86,	RMSE = 1.0830,	time = 0.05s
# (2,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.89,	RMSE = 1.0904,	time = 0.07s
# (2,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.00,	RMSE = 1.2465,	time = 0.04s
# (2,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.54,	RMSE = 1.0778,	time = 0.08s
# (2,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.76,	RMSE = 1.0819,	time = 0.07s
# (2,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.83,	RMSE = 1.0820,	time = 0.10s
# (2,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.09,	RMSE = 1.2150,	time = 0.03s
# (2,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 1.0967,	time = 0.08s
# (3,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.07,	RMSE = 1.1374,	time = 0.02s
# (3,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.37,	RMSE = 1.1368,	time = 0.04s
# (3,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 1.0891,	time = 0.17s
# (3,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.93,	RMSE = 1.0918,	time = 0.11s
# (3,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.10,	RMSE = 1.1124,	time = 0.04s
# (3,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.36,	RMSE = 1.1213,	time = 0.06s
# (3,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.91,	RMSE = 1.0917,	time = 0.08s
# (3,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.71,	RMSE = 1.0542,	time = 0.16s
# (3,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.30,	RMSE = 1.1792,	time = 0.04s
# (3,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.73,	RMSE = 1.0862,	time = 0.11s
# (4,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.85,	RMSE = 1.0525,	time = 0.03s
# (4,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.91,	RMSE = 1.0646,	time = 0.06s
# (4,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.90,	RMSE = 1.0603,	time = 0.10s
# (4,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.79,	RMSE = 1.0876,	time = 0.11s
# (4,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 1.0808,	time = 0.08s
# Best RMSE:  1.0525
# Retail_Sales_Mth : Best parameters : (4,1,2)(0,0,0)[4]
#
#  Traversing the SARIMA equations of Imports_Mth ...
# (2,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.99,	RMSE = 1.8482,	time = 0.04s
# (2,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.70,	RMSE = 1.2903,	time = 0.04s
# (2,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 1.3422,	time = 0.03s
# (2,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.57,	RMSE = 1.2152,	time = 0.04s
# (2,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.91,	RMSE = 1.3802,	time = 0.05s
# (2,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.9701,	time = 0.06s
# (2,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.93,	RMSE = 1.0306,	time = 0.05s
# (2,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.9441,	time = 0.08s
# (2,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 1.2334,	time = 0.04s
# (2,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 1.0684,	time = 0.04s
# (3,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.80,	RMSE = 1.7895,	time = 0.03s
# (3,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.80,	RMSE = 1.2635,	time = 0.05s
# (3,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 1.3323,	time = 0.04s
# (3,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.94,	RMSE = 1.1689,	time = 0.05s
# (3,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.89,	RMSE = 1.3887,	time = 0.05s
# (3,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.77,	RMSE = 1.0136,	time = 0.10s
# (3,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.9990,	time = 0.11s
# (3,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.88,	RMSE = 1.0132,	time = 0.09s
# (3,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.72,	RMSE = 1.0336,	time = 0.05s
# (3,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 1.1902,	time = 0.07s
# (4,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.59,	RMSE = 0.9071,	time = 0.04s
# (4,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.48,	RMSE = 0.9993,	time = 0.07s
# (4,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.9193,	time = 0.06s
# (4,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.80,	RMSE = 1.0855,	time = 0.11s
# (4,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.65,	RMSE = 1.1605,	time = 0.06s
# Best RMSE:  0.9071
# Imports_Mth : Best parameters : (4,0,2)(0,0,0)[4]
#
#  Traversing the SARIMA equations of Exports_Mth ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.01,	RMSE = 1.3306,	time = 0.04s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.07,	RMSE = 1.0286,	time = 0.05s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.54,	RMSE = 1.2241,	time = 0.05s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.33,	RMSE = 0.9937,	time = 0.08s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.14,	RMSE = 1.2373,	time = 0.04s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.54,	RMSE = 1.0057,	time = 0.09s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.9696,	time = 0.07s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.83,	RMSE = 1.0086,	time = 0.10s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.24,	RMSE = 1.4283,	time = 0.05s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.10,	RMSE = 1.1015,	time = 0.05s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.81,	RMSE = 1.4026,	time = 0.03s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.45,	RMSE = 1.0164,	time = 0.06s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 1.00,	RMSE = 1.0311,	time = 0.05s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.68,	RMSE = 0.9791,	time = 0.06s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 1.0322,	time = 0.03s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.9721,	time = 0.08s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.71,	RMSE = 0.9950,	time = 0.05s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.9802,	time = 0.09s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.32,	RMSE = 1.0522,	time = 0.04s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.9019,	time = 0.10s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.80,	RMSE = 1.4015,	time = 0.09s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.37,	RMSE = 1.0134,	time = 0.11s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 1.2075,	time = 0.09s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.93,	RMSE = 0.9925,	time = 0.13s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.55,	RMSE = 0.9682,	time = 0.06s
# Best RMSE:  0.9019
# Exports_Mth : Best parameters : (3,2,4)(1,0,0)[4]
#
#  Traversing the SARIMA equations of M1 ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.73,	RMSE = 0.5145,	time = 0.04s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.4150,	time = 0.05s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.4236,	time = 0.05s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 1.00,	RMSE = 0.4239,	time = 0.06s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.5098,	time = 0.04s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.54,	RMSE = 0.4685,	time = 0.06s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.4219,	time = 0.07s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.30,	RMSE = 0.3701,	time = 0.12s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.02,	RMSE = 0.5077,	time = 0.04s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.27,	RMSE = 0.4179,	time = 0.06s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.5089,	time = 0.03s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.4178,	time = 0.05s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.4572,	time = 0.03s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.4100,	time = 0.06s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.5021,	time = 0.04s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.4145,	time = 0.05s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.74,	RMSE = 0.4601,	time = 0.04s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.83,	RMSE = 0.4103,	time = 0.06s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.53,	RMSE = 0.4042,	time = 0.05s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.3802,	time = 0.08s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.72,	RMSE = 0.4937,	time = 0.14s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.4268,	time = 0.13s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 1.00,	RMSE = 0.4627,	time = 0.09s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.28,	RMSE = 0.3929,	time = 0.14s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.56,	RMSE = 0.3432,	time = 0.06s
# Best RMSE:  0.3432
# M1 : Best parameters : (4,2,4)(0,0,0)[4]
#
#  Traversing the SARIMA equations of M2 ...
# (2,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.3738,	time = 0.04s
# (2,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.29,	RMSE = 0.2104,	time = 0.11s
# (2,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.93,	RMSE = 0.2266,	time = 0.06s
# (2,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1589,	time = 0.10s
# (2,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.74,	RMSE = 0.2724,	time = 0.07s
# (2,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.50,	RMSE = 0.2804,	time = 0.10s
# (2,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.27,	RMSE = 0.1914,	time = 0.13s
# (2,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.1668,	time = 0.15s
# (2,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.59,	RMSE = 0.2232,	time = 0.08s
# (2,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.74,	RMSE = 0.1529,	time = 0.10s
# (3,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.01,	RMSE = 0.7546,	time = 0.06s
# (3,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.22,	RMSE = 0.6776,	time = 0.13s
# (3,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.32,	RMSE = 0.2322,	time = 0.11s
# (3,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.34,	RMSE = 0.1771,	time = 0.15s
# (3,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.06,	RMSE = 0.2491,	time = 0.08s
# (3,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.70,	RMSE = 0.2748,	time = 0.12s
# (3,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.58,	RMSE = 0.1757,	time = 0.12s
# (3,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.52,	RMSE = 0.1532,	time = 0.13s
# (3,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.2325,	time = 0.10s
# (3,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.1781,	time = 0.11s
# (4,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.48,	RMSE = 0.3200,	time = 0.08s
# (4,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.46,	RMSE = 0.2632,	time = 0.12s
# (4,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.07,	RMSE = 0.2520,	time = 0.09s
# (4,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.17,	RMSE = 0.2355,	time = 0.11s
# (4,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.2331,	time = 0.11s
# Best RMSE:  0.1529
# M2 : Best parameters : (2,0,4)(1,0,0)[4]
#
#  Traversing the SARIMA equations of Loans_RMB ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.29,	RMSE = 0.1978,	time = 0.04s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.1255,	time = 0.07s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.1139,	time = 0.07s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.73,	RMSE = 0.0933,	time = 0.10s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.43,	RMSE = 0.1496,	time = 0.04s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.58,	RMSE = 0.1137,	time = 0.10s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.1073,	time = 0.07s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.77,	RMSE = 0.0891,	time = 0.10s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.00,	RMSE = 0.1624,	time = 0.08s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.06,	RMSE = 0.1034,	time = 0.09s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.17,	RMSE = 0.1375,	time = 0.06s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.66,	RMSE = 0.0983,	time = 0.09s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.1212,	time = 0.06s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.76,	RMSE = 0.0934,	time = 0.13s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.48,	RMSE = 0.1157,	time = 0.05s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.39,	RMSE = 0.0952,	time = 0.16s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.1150,	time = 0.10s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.42,	RMSE = 0.0870,	time = 0.09s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.47,	RMSE = 0.1102,	time = 0.09s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.56,	RMSE = 0.0896,	time = 0.14s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1441,	time = 0.08s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1030,	time = 0.11s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.48,	RMSE = 0.1157,	time = 0.11s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.0927,	time = 0.12s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.1123,	time = 0.09s
# Best RMSE:  0.0870
# Loans_RMB : Best parameters : (3,2,3)(1,0,1)[4]
#
#  Traversing the SARIMA equations of Social_Financing ...
# (2,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.45,	RMSE = 0.3976,	time = 0.03s
# (2,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.58,	RMSE = 0.4084,	time = 0.04s
# (2,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.3967,	time = 0.04s
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# (2,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.3701,	time = 0.11s
# (2,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.54,	RMSE = 0.4341,	time = 0.03s
# (2,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.50,	RMSE = 0.4212,	time = 0.04s
# (2,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.49,	RMSE = 0.3907,	time = 0.03s
# (2,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.44,	RMSE = 0.4321,	time = 0.05s
# (2,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.80,	RMSE = 0.4052,	time = 0.07s
# (2,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.3634,	time = 0.06s
# (3,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.57,	RMSE = 0.3979,	time = 0.04s
# (3,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.44,	RMSE = 0.3946,	time = 0.04s
# (3,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.35,	RMSE = 0.4055,	time = 0.04s
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# (3,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.33,	RMSE = 0.4117,	time = 0.07s
# (3,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.55,	RMSE = 0.4358,	time = 0.04s
# (3,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.52,	RMSE = 0.4487,	time = 0.05s
# (3,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.4037,	time = 0.06s
# (3,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.45,	RMSE = 0.4384,	time = 0.06s
# (3,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.3845,	time = 0.06s
# (3,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.3617,	time = 0.11s
# (4,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.64,	RMSE = 0.4336,	time = 0.07s
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# (4,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.54,	RMSE = 0.3947,	time = 0.06s
# (4,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.55,	RMSE = 0.4369,	time = 0.09s
# (4,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.34,	RMSE = 0.4082,	time = 0.06s
# (4,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.67,	RMSE = 0.4321,	time = 0.10s
# Best RMSE:  0.3617
# Social_Financing : Best parameters : (3,1,4)(1,0,0)[4]
#
#  Traversing the SARIMA equations of Manuf_PMI ...
# (2,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.5111,	time = 0.07s
# (2,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.75,	RMSE = 0.5041,	time = 0.11s
# (2,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.2393,	time = 0.08s
# (2,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.1904,	time = 0.10s
# (2,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.5632,	time = 0.06s
# (2,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.93,	RMSE = 0.5215,	time = 0.11s
# (2,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.2370,	time = 0.08s
# (2,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.1836,	time = 0.11s
# (2,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.25,	RMSE = 0.3594,	time = 0.09s
# (2,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.1581,	time = 0.11s
# (3,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.5363,	time = 0.06s
# (3,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.5103,	time = 0.07s
# (3,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.58,	RMSE = 0.2716,	time = 0.09s
# (3,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.1689,	time = 0.12s
# (3,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.5193,	time = 0.07s
# (3,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.50,	RMSE = 0.5519,	time = 0.12s
# (3,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.55,	RMSE = 0.2435,	time = 0.11s
# (3,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.1853,	time = 0.12s
# (3,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.18,	RMSE = 0.3471,	time = 0.08s
# (3,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.83,	RMSE = 0.1923,	time = 0.12s
# (4,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.3473,	time = 0.07s
# (4,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.71,	RMSE = 0.3220,	time = 0.09s
# (4,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.81,	RMSE = 0.3542,	time = 0.08s
# (4,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.65,	RMSE = 0.3190,	time = 0.10s
# (4,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.36,	RMSE = 0.2256,	time = 0.09s
# Best RMSE:  0.1581
# Manuf_PMI : Best parameters : (2,0,4)(1,0,0)[4]
#
#  Traversing the SARIMA equations of Ind_Revenue_Cum ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.10,	RMSE = 0.9726,	time = 0.03s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.21,	RMSE = 0.5643,	time = 0.04s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.15,	RMSE = 0.5511,	time = 0.03s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.59,	RMSE = 0.3812,	time = 0.04s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.38,	RMSE = 0.8092,	time = 0.04s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.42,	RMSE = 0.4904,	time = 0.06s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.47,	RMSE = 0.4983,	time = 0.04s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.52,	RMSE = 0.3622,	time = 0.07s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.08,	RMSE = 0.7940,	time = 0.05s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.07,	RMSE = 0.5280,	time = 0.06s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.7357,	time = 0.04s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.3938,	time = 0.04s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.75,	RMSE = 0.5708,	time = 0.04s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.4115,	time = 0.07s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.61,	RMSE = 0.5834,	time = 0.03s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.64,	RMSE = 0.3964,	time = 0.05s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.61,	RMSE = 0.5039,	time = 0.07s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.47,	RMSE = 0.4107,	time = 0.07s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.5853,	time = 0.04s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.73,	RMSE = 0.4596,	time = 0.06s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.80,	RMSE = 0.7128,	time = 0.07s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.73,	RMSE = 0.3936,	time = 0.09s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.57,	RMSE = 0.4613,	time = 0.07s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.93,	RMSE = 0.4024,	time = 0.10s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.3988,	time = 0.06s
# Best RMSE:  0.3622
# Ind_Revenue_Cum : Best parameters : (2,2,3)(1,0,1)[4]
#
#  Traversing the SARIMA equations of PPIRM_Mth ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.2725,	time = 0.03s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.74,	RMSE = 0.1784,	time = 0.06s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.63,	RMSE = 0.1837,	time = 0.05s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.1460,	time = 0.05s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.72,	RMSE = 0.2734,	time = 0.05s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.46,	RMSE = 0.1654,	time = 0.07s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.1987,	time = 0.07s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.60,	RMSE = 0.1495,	time = 0.08s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.70,	RMSE = 0.2201,	time = 0.04s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.18,	RMSE = 0.1798,	time = 0.07s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.2442,	time = 0.03s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.81,	RMSE = 0.1616,	time = 0.09s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1888,	time = 0.04s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1559,	time = 0.07s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.41,	RMSE = 0.2161,	time = 0.04s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.1402,	time = 0.10s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.74,	RMSE = 0.1515,	time = 0.06s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.1426,	time = 0.14s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.77,	RMSE = 0.1682,	time = 0.06s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.71,	RMSE = 0.1725,	time = 0.09s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 2186.3361,	time = 0.03s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.01,	RMSE = 1360.5836,	time = 0.02s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.10,	RMSE = 0.2101,	time = 0.09s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1618,	time = 0.12s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.1681,	time = 0.12s
# Best RMSE:  0.1402
# PPIRM_Mth : Best parameters : (3,2,3)(0,0,1)[4]
#
#  Traversing the SARIMA equations of CGPI_Mth ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.70,	RMSE = 0.1731,	time = 0.05s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.1417,	time = 0.05s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.85,	RMSE = 0.1471,	time = 0.05s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.1455,	time = 0.06s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.1747,	time = 0.04s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.1411,	time = 0.06s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.1430,	time = 0.05s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.1395,	time = 0.06s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.21,	RMSE = 0.1890,	time = 0.06s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.58,	RMSE = 0.1576,	time = 0.07s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.2137,	time = 0.03s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.85,	RMSE = 0.1441,	time = 0.07s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.1724,	time = 0.05s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.1521,	time = 0.08s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.46,	RMSE = 0.1676,	time = 0.05s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1392,	time = 0.09s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.66,	RMSE = 0.1491,	time = 0.07s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.1444,	time = 0.12s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.1624,	time = 0.06s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.1538,	time = 0.09s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.97,	RMSE = 164.3207,	time = 0.07s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.23,	RMSE = 126.8773,	time = 0.04s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.1492,	time = 0.11s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.64,	RMSE = 0.1537,	time = 0.12s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.97,	RMSE = 0.1561,	time = 0.09s
# Best RMSE:  0.1392
# CGPI_Mth : Best parameters : (3,2,3)(0,0,1)[4]
#
#  Traversing the SARIMA equations of 70_Cities_Price_Mth ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.64,	RMSE = 0.1303,	time = 0.04s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.83,	RMSE = 0.0984,	time = 0.07s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.1077,	time = 0.08s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.0924,	time = 0.11s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.1217,	time = 0.05s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.97,	RMSE = 0.1107,	time = 0.11s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.1091,	time = 0.07s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.0904,	time = 0.12s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.60,	RMSE = 0.1044,	time = 0.08s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.1056,	time = 0.08s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.66,	RMSE = 0.1174,	time = 0.04s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.1105,	time = 0.08s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.84,	RMSE = 0.1047,	time = 0.07s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.97,	RMSE = 0.0942,	time = 0.09s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.28,	RMSE = 0.1396,	time = 0.04s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.1027,	time = 0.11s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.0999,	time = 0.09s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.97,	RMSE = 0.0916,	time = 0.12s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.71,	RMSE = 0.1019,	time = 0.09s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.0974,	time = 0.12s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.1233,	time = 0.08s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.20,	RMSE = 0.1106,	time = 0.11s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.81,	RMSE = 0.1189,	time = 0.09s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.1024,	time = 0.14s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.57,	RMSE = 0.0975,	time = 0.10s
# Best RMSE:  0.0904
# 70_Cities_Price_Mth : Best parameters : (2,2,3)(1,0,1)[4]
#
#  Traversing the SARIMA equations of Power_Gen_Mth ...
# (2,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.6402,	time = 0.02s
# (2,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.56,	RMSE = 0.5022,	time = 0.03s
# (2,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.5578,	time = 0.03s
# (2,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.75,	RMSE = 0.4300,	time = 0.08s
# (2,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.5602,	time = 0.04s
# (2,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.4998,	time = 0.05s
# (2,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.22,	RMSE = 0.4424,	time = 0.06s
# (2,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.62,	RMSE = 0.4004,	time = 0.09s
# (2,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.66,	RMSE = 0.4692,	time = 0.04s
# (2,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.54,	RMSE = 0.4146,	time = 0.05s
# (3,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.09,	RMSE = 0.5511,	time = 0.04s
# (3,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.66,	RMSE = 0.4490,	time = 0.04s
# (3,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.45,	RMSE = 0.4574,	time = 0.05s
# (3,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.56,	RMSE = 0.4474,	time = 0.05s
# (3,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.50,	RMSE = 0.4707,	time = 0.06s
# (3,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.61,	RMSE = 0.3708,	time = 0.10s
# (3,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.3949,	time = 0.07s
# (3,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.3821,	time = 0.10s
# (3,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.77,	RMSE = 0.4733,	time = 0.04s
# (3,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.3269,	time = 0.07s
# (4,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.84,	RMSE = 0.5826,	time = 0.06s
# (4,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.4426,	time = 0.07s
# (4,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.93,	RMSE = 0.5808,	time = 0.05s
# (4,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.88,	RMSE = 0.4237,	time = 0.08s
# (4,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.4382,	time = 0.05s
# Best RMSE:  0.3269
# Power_Gen_Mth : Best parameters : (3,1,4)(1,0,0)[4]
#
#  Traversing the SARIMA equations of Freight_Mth ...
# (2,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 4.9524,	time = 0.06s
# (2,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.94,	RMSE = 4.4867,	time = 0.08s
# (2,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.85,	RMSE = 4.7284,	time = 0.07s
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# (2,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.99,	RMSE = 4.2623,	time = 0.10s
# (2,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.69,	RMSE = 4.9970,	time = 0.05s
# (2,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.86,	RMSE = 4.5834,	time = 0.07s
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# (2,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.88,	RMSE = 4.7185,	time = 0.09s
# (2,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.85,	RMSE = 4.2295,	time = 0.10s
# (2,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.83,	RMSE = 4.6108,	time = 0.08s
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# (2,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 4.4859,	time = 0.07s
# (3,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 4.8932,	time = 0.08s
# (3,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.99,	RMSE = 4.4614,	time = 0.06s
# (3,0,2)(1,0,0)[4],	Ljung-Box(Q) = 0.93,	RMSE = 4.6238,	time = 0.10s
# (3,0,2)(1,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 4.2382,	time = 0.11s
# (3,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.69,	RMSE = 5.0217,	time = 0.08s
# (3,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.91,	RMSE = 4.4332,	time = 0.11s
# (3,0,3)(1,0,0)[4],	Ljung-Box(Q) = 0.80,	RMSE = 4.6739,	time = 0.09s
# (3,0,3)(1,0,1)[4],	Ljung-Box(Q) = 0.97,	RMSE = 3.8175,	time = 0.11s
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# (3,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.80,	RMSE = 4.5831,	time = 0.09s
# (3,0,4)(1,0,0)[4],	Ljung-Box(Q) = 0.89,	RMSE = 4.4578,	time = 0.10s
# (4,0,2)(0,0,0)[4],	Ljung-Box(Q) = 0.38,	RMSE = 4.7278,	time = 0.05s
# (4,0,2)(0,0,1)[4],	Ljung-Box(Q) = 0.97,	RMSE = 4.4426,	time = 0.09s
# (4,0,3)(0,0,0)[4],	Ljung-Box(Q) = 0.71,	RMSE = 4.6656,	time = 0.08s
# (4,0,3)(0,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 4.3642,	time = 0.10s
# (4,0,4)(0,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 4.5353,	time = 0.09s
# Best RMSE:  3.8175
# Freight_Mth : Best parameters : (3,0,3)(1,0,1)[4]
#
#  Traversing the SARIMA equations of Urban_Income_Cum ...
# (2,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.38,	RMSE = 0.1652,	time = 0.06s
# (2,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.20,	RMSE = 0.1453,	time = 0.09s
# (2,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.1074,	time = 0.06s
# (2,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.1099,	time = 0.07s
# (2,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.75,	RMSE = 0.1443,	time = 0.06s
# (2,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.02,	RMSE = 0.1643,	time = 0.10s
# (2,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.84,	RMSE = 0.1156,	time = 0.06s
# (2,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.97,	RMSE = 0.0821,	time = 0.12s
# (2,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.05,	RMSE = 0.1535,	time = 0.09s
# (2,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.1137,	time = 0.10s
# (3,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.28,	RMSE = 0.1486,	time = 0.05s
# (3,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.85,	RMSE = 0.1212,	time = 0.10s
# (3,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.1037,	time = 0.08s
# (3,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.77,	RMSE = 0.1031,	time = 0.08s
# (3,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.56,	RMSE = 0.1479,	time = 0.09s
# (3,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.1189,	time = 0.11s
# (3,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.74,	RMSE = 0.1068,	time = 0.09s
# (3,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.92,	RMSE = 0.0899,	time = 0.13s
# (3,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.04,	RMSE = 0.1288,	time = 0.06s
# (3,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.62,	RMSE = 0.0838,	time = 0.10s
# (4,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.1026,	time = 0.04s
# (4,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.0978,	time = 0.10s
# (4,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.60,	RMSE = 0.1062,	time = 0.06s
# (4,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.0969,	time = 0.11s
# (4,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.89,	RMSE = 0.1058,	time = 0.06s
# Best RMSE:  0.0821
# Urban_Income_Cum : Best parameters : (2,1,3)(1,0,1)[4]
#
#  Traversing the SARIMA equations of Urban_Exp_Cum ...
# (2,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.4649,	time = 0.04s
# (2,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.75,	RMSE = 0.3062,	time = 0.06s
# (2,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.2916,	time = 0.06s
# (2,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.2926,	time = 0.09s
# (2,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.76,	RMSE = 0.3767,	time = 0.04s
# (2,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.43,	RMSE = 0.3137,	time = 0.07s
# (2,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.77,	RMSE = 0.2987,	time = 0.07s
# (2,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.77,	RMSE = 0.3026,	time = 0.08s
# (2,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.41,	RMSE = 0.3635,	time = 0.05s
# (2,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.91,	RMSE = 0.2896,	time = 0.07s
# (3,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.75,	RMSE = 0.4245,	time = 0.03s
# (3,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.69,	RMSE = 0.3020,	time = 0.06s
# (3,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.4013,	time = 0.09s
# (3,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.84,	RMSE = 0.3759,	time = 0.06s
# (3,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 0.3766,	time = 0.06s
# (3,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.76,	RMSE = 0.2971,	time = 0.12s
# (3,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.2901,	time = 0.07s
# (3,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.2877,	time = 0.11s
# (3,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.40,	RMSE = 0.3428,	time = 0.09s
# (3,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.3055,	time = 0.08s
# (4,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.71,	RMSE = 0.3966,	time = 0.05s
# (4,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.69,	RMSE = 0.3797,	time = 0.07s
# (4,1,3)(0,0,0)[4],	Ljung-Box(Q) = 1.00,	RMSE = 0.2995,	time = 0.05s
# (4,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.3000,	time = 0.08s
# (4,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.97,	RMSE = 0.2978,	time = 0.06s
# Best RMSE:  0.2877
# Urban_Exp_Cum : Best parameters : (3,1,3)(1,0,1)[4]
#
#  Traversing the SARIMA equations of Nat_Housing_Index ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.97,	RMSE = 0.5761,	time = 0.04s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.94,	RMSE = 0.2648,	time = 0.05s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.24,	RMSE = 0.1191,	time = 0.06s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.73,	RMSE = 0.1028,	time = 0.08s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.72,	RMSE = 0.4294,	time = 0.06s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.62,	RMSE = 0.1991,	time = 0.10s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.65,	RMSE = 0.1341,	time = 0.08s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.84,	RMSE = 0.0960,	time = 0.17s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.41,	RMSE = 0.3089,	time = 0.04s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.33,	RMSE = 0.1078,	time = 0.11s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.1721,	time = 0.03s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.53,	RMSE = 0.0960,	time = 0.06s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.32,	RMSE = 0.0926,	time = 0.05s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.66,	RMSE = 0.0994,	time = 0.07s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.14,	RMSE = 0.1421,	time = 0.04s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.24,	RMSE = 0.0971,	time = 0.08s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.56,	RMSE = 0.0982,	time = 0.06s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.68,	RMSE = 0.1052,	time = 0.08s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.56,	RMSE = 0.1049,	time = 0.06s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.79,	RMSE = 0.1024,	time = 0.08s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1729,	time = 0.09s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.0980,	time = 0.12s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.96,	RMSE = 0.1650,	time = 0.13s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.01,	RMSE = 0.3874,	time = 0.17s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.1057,	time = 0.07s
# Best RMSE:  0.0926
# Nat_Housing_Index : Best parameters : (3,2,2)(1,0,0)[4]
#
#  Traversing the SARIMA equations of Macro_Eco_Index ...
# (2,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.12,	RMSE = 0.5010,	time = 0.03s
# (2,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.57,	RMSE = 0.2675,	time = 0.07s
# (2,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.32,	RMSE = 0.2726,	time = 0.05s
# (2,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.76,	RMSE = 0.2113,	time = 0.07s
# (2,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.53,	RMSE = 0.3530,	time = 0.04s
# (2,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.2608,	time = 0.07s
# (2,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.86,	RMSE = 0.2554,	time = 0.07s
# (2,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.95,	RMSE = 0.2173,	time = 0.11s
# (2,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.02,	RMSE = 0.4169,	time = 0.04s
# (2,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.29,	RMSE = 0.2695,	time = 0.06s
# (3,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 0.3262,	time = 0.03s
# (3,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.90,	RMSE = 0.2566,	time = 0.09s
# (3,2,2)(1,0,0)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.1909,	time = 0.04s
# (3,2,2)(1,0,1)[4],	Ljung-Box(Q) = 0.80,	RMSE = 0.1760,	time = 0.12s
# (3,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.73,	RMSE = 0.2911,	time = 0.05s
# (3,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.98,	RMSE = 0.2274,	time = 0.07s
# (3,2,3)(1,0,0)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.2475,	time = 0.06s
# (3,2,3)(1,0,1)[4],	Ljung-Box(Q) = 0.93,	RMSE = 0.2140,	time = 0.08s
# (3,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.45,	RMSE = 0.1963,	time = 0.06s
# (3,2,4)(1,0,0)[4],	Ljung-Box(Q) = 0.55,	RMSE = 0.1943,	time = 0.06s
# (4,2,2)(0,0,0)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.3296,	time = 0.08s
# (4,2,2)(0,0,1)[4],	Ljung-Box(Q) = 0.82,	RMSE = 0.2091,	time = 0.14s
# (4,2,3)(0,0,0)[4],	Ljung-Box(Q) = 0.74,	RMSE = 0.2906,	time = 0.05s
# (4,2,3)(0,0,1)[4],	Ljung-Box(Q) = 0.99,	RMSE = 0.2250,	time = 0.10s
# (4,2,4)(0,0,0)[4],	Ljung-Box(Q) = 0.76,	RMSE = 0.1803,	time = 0.09s
# Best RMSE:  0.1760
# Macro_Eco_Index : Best parameters : (3,2,2)(1,0,1)[4]
#
#  Traversing the SARIMA equations of Housing_Sales_Cum ...
# (2,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.14,	RMSE = 4.3481,	time = 0.03s
# (2,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.06,	RMSE = 2.2943,	time = 0.04s
# (2,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.87,	RMSE = 1.9775,	time = 0.05s
# (2,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.67,	RMSE = 1.8643,	time = 0.05s
# (2,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.45,	RMSE = 4.3864,	time = 0.05s
# (2,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.78,	RMSE = 2.3589,	time = 0.06s
# (2,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.76,	RMSE = 1.9715,	time = 0.05s
# (2,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.83,	RMSE = 1.6298,	time = 0.08s
# (2,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.18,	RMSE = 2.9898,	time = 0.03s
# (2,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.78,	RMSE = 1.6696,	time = 0.03s
# (3,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.30,	RMSE = 3.4775,	time = 0.02s
# (3,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.53,	RMSE = 2.2980,	time = 0.06s
# (3,1,2)(1,0,0)[4],	Ljung-Box(Q) = 0.80,	RMSE = 1.9761,	time = 0.08s
# (3,1,2)(1,0,1)[4],	Ljung-Box(Q) = 0.83,	RMSE = 1.8890,	time = 0.05s
# (3,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.47,	RMSE = 4.0712,	time = 0.05s
# (3,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.88,	RMSE = 2.2044,	time = 0.07s
# (3,1,3)(1,0,0)[4],	Ljung-Box(Q) = 0.76,	RMSE = 2.0438,	time = 0.06s
# (3,1,3)(1,0,1)[4],	Ljung-Box(Q) = 0.57,	RMSE = 1.5847,	time = 0.07s
# (3,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.54,	RMSE = 2.6293,	time = 0.03s
# (3,1,4)(1,0,0)[4],	Ljung-Box(Q) = 0.79,	RMSE = 1.6861,	time = 0.04s
# (4,1,2)(0,0,0)[4],	Ljung-Box(Q) = 0.98,	RMSE = 2.4537,	time = 0.05s
# (4,1,2)(0,0,1)[4],	Ljung-Box(Q) = 0.88,	RMSE = 1.5867,	time = 0.07s
# (4,1,3)(0,0,0)[4],	Ljung-Box(Q) = 0.72,	RMSE = 2.3177,	time = 0.05s
# (4,1,3)(0,0,1)[4],	Ljung-Box(Q) = 0.67,	RMSE = 1.7175,	time = 0.07s
# (4,1,4)(0,0,0)[4],	Ljung-Box(Q) = 0.49,	RMSE = 2.2232,	time = 0.09s
# Best RMSE:  1.5847
# Housing_Sales_Cum : Best parameters : (3,1,3)(1,0,1)[4]
# The prediction process took a total of 0.78 minutes.
