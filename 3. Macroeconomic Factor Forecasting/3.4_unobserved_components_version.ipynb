# %% [markdown]
# *https://github.com/Aubrey-Bermuda-CA/IFRS9-MODELING-CHINA*

# %% [markdown]
# *3.4 Functional description: Read macro historical data and external forecast data, and use the Unobserved components model to predict macro data.*

# %%
import time
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.statespace.structural import UnobservedComponents

# %%
# set date range
start_date = '2010-03-31'
forecast_date = '2026-09-30'
date_index = pd.date_range(start=start_date, end=forecast_date, freq='Q')

# read macro data
macro_his_data = pd.read_csv(f'./macrofactor_historical_data.csv', index_col=[0], parse_dates=[0])
macro_fc_data = pd.read_csv(f'./macrofactor_forecast_data.csv', index_col=[0], parse_dates=[0])

# combine data
macro_data = macro_his_data.combine_first(macro_fc_data)

# Missing values ​​can be handled using interpolation. There are several methods to choose from:
# 'linear', 'nearest', 'zero', 'slinear', 'quadratic', 'cubic', 'barycentric', 'polynomial', 
# 'krogh', 'piecewise_polynomial', 'spline', 'pchip', 'akima', 'cubicspline'
# macro_data = macro_data.interpolate(method='spline')

macro_data
# Out:
#             GDP_Const_Qtr  Ind_Pro_Mth  CPI_Mth  Core_CPI_Mth  PPI_Mth  \
# date
# 2010-03-31          12.20         18.1  102.400           NaN     5.91
# 2010-06-30          10.80         13.7  102.900           NaN     6.41
# 2010-09-30           9.90         13.3  103.600           NaN     4.33
# 2010-12-31           9.90         13.5  104.600           NaN     5.93
# 2011-03-31          10.20         14.8  105.383           NaN     7.31
# ...                   ...          ...      ...           ...      ...
# 2024-09-30           4.60          5.4  100.400           0.1    -2.80
# 2024-12-31           4.85          NaN    1.800           0.7    -2.20
# 2025-03-31           4.00          NaN      NaN           NaN      NaN
# 2025-06-30           4.55          NaN      NaN           NaN      NaN
# 2025-09-30           4.20          NaN      NaN           NaN      NaN
#
#             FAI_Cum  Retail_Sales_Mth  Imports_Mth  Exports_Mth     M1  ...  \
# date                                                                    ...
# 2010-03-31     26.4             18.00        66.27        24.21  29.94  ...
# 2010-06-30     25.5             18.30        33.87        43.87  24.56  ...
# 2010-09-30     24.5             18.84        24.38        25.08  20.87  ...
# 2010-12-31     24.5             19.10        25.94        17.87  21.19  ...
# 2011-03-31     25.0             17.40        27.50        35.76  15.00  ...
# ...             ...               ...          ...          ...    ...  ...
# 2024-09-30      3.4              3.20         0.30         2.40  -7.40  ...
# 2024-12-31      3.0              6.40        11.00          NaN  -6.50  ...
# 2025-03-31      3.6               NaN          NaN          NaN    NaN  ...
# 2025-06-30      3.9               NaN          NaN          NaN    NaN  ...
# 2025-09-30      4.0               NaN          NaN          NaN    NaN  ...
#
#             PPIRM_Mth  CGPI_Mth  70_Cities_Price_Mth  Power_Gen_Mth  \
# date
# 2010-03-31      11.46     105.6                  9.5           17.6
# 2010-06-30      10.80     106.6                  7.7           11.4
# 2010-09-30       7.10     106.1                  6.2            8.1
# 2010-12-31       9.47     107.9                  5.0            5.1
# 2011-03-31      10.53     109.3                  3.7           14.8
# ...               ...       ...                  ...            ...
# 2024-09-30      -2.20      98.3                 -9.0            6.0
# 2024-12-31        NaN       NaN                  NaN            NaN
# 2025-03-31        NaN       NaN                  NaN            NaN
# 2025-06-30        NaN       NaN                  NaN            NaN
# 2025-09-30        NaN       NaN                  NaN            NaN
#
#             Freight_Mth  Urban_Income_Cum  Urban_Exp_Cum  Nat_Housing_Index  \
# date
# 2010-03-31    15.800000               9.8          11.01             105.89
# 2010-06-30    12.300000              10.2           9.89             105.06
# 2010-09-30    11.900000              10.5           9.32             103.52
# 2010-12-31     0.310000              11.3           9.84             101.79
# 2011-03-31    14.300000              12.3          10.69             102.98
# ...                 ...               ...            ...                ...
# 2024-09-30     2.315156               4.5           5.00              92.40
# 2024-12-31          NaN               NaN            NaN                NaN
# 2025-03-31          NaN               NaN            NaN                NaN
# 2025-06-30          NaN               NaN            NaN                NaN
# 2025-09-30          NaN               NaN            NaN                NaN
#
#             Macro_Eco_Index  Housing_Sales_Cum
# date
# 2010-03-31            104.0               57.7
# 2010-06-30            102.6               25.4
# 2010-09-30            101.9               15.9
# 2010-12-31            103.6               18.3
# 2011-03-31            102.5               27.3
# ...                     ...                ...
# 2024-09-30              NaN              -22.7
# 2024-12-31              NaN                NaN
# 2025-03-31              NaN                NaN
# 2025-06-30              NaN                NaN
# 2025-09-30              NaN                NaN
#
# [63 rows x 25 columns]

# %%
# The method used here comes from this article ：https://www.ecb.europa.eu/pub/pdf/scpwps/ecbwp499.pdf. 
# This is just a simple attempt, not a reproduction of the article.
# As concluded in the article, hpfilter obtain more stable predictive values.

# Use Hodrick-Prescott filter to separate trend terms and periodic terms
macro_data_fitted = pd.DataFrame(index=macro_data.index)

for column in macro_data:
    y = macro_data[column].dropna()
    cycle, trend = sm.tsa.filters.hpfilter(y)
    try:
        result = STL(cycle).fit()
        seasonal = result.seasonal
        seasonal = seasonal.rename(column)
        seasonal_smooth = seasonal[abs(seasonal - seasonal.mean()) <= 2.576 * seasonal.std()] # 99% confidence level value
        fitted = trend.add(seasonal_smooth, fill_value=0)
    except:
        seasonal = pd.DataFrame(index=trend.index, columns=[column])
        cycle_smooth = cycle[abs(cycle - cycle.mean()) <= 2.576 * cycle.std()]
        fitted = trend.add(cycle_smooth, fill_value=0)
    
    # # Create a graphics object
    # fig, ax1 = plt.subplots(figsize=(10, 5))
    # ax1.plot(y.index, y, label=column, color='g')
    # ax1.plot(y.index, fitted, label='Fitted', color='b')
    # ax1.set_xlabel('Date')
    # ax1.set_ylabel('Value and Fitted')
    # ax1.legend(loc='upper left')

    # # Create a secondary axis
    # ax2 = ax1.twinx() 
    # ax2.plot(y.index, seasonal, label='Seasonal', color='gray', linestyle='--')
    # ax2.set_ylabel('Seasonal', color='k')
    # ax2.legend(loc='upper right')
    # plt.title('Original, Seasonal and Fitted (HP filter)')
    # plt.show()

    macro_data_fitted = macro_data_fitted.merge(fitted.rename(column), left_index=True, right_index=True, how='left')

macro_data_fitted.to_csv(f'./macro_data_fitted.csv')

# %%
# to avoid Maximum Likelihood convergence warning
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='statsmodels')

df = macro_data_fitted
# Set the frequency
df = df.asfreq('Q-DEC')

# save model result
predict_data = pd.DataFrame(index=date_index)
print(f'macrofoctor_list：{df.columns.values}')

# timer
start_t = time.perf_counter()

# loss function, You can customize your own loss function
def func_calc_rmse(y, y_pred):
    try:
        res_rmse = np.sqrt(np.mean((y[-16:-4] - y_pred[-16:-4]) ** 2))
    except:
        res_rmse = np.inf
    return res_rmse

# Unobserved components model
# The method used here is mentioned in this article ：https://www.ecb.europa.eu/pub/pdf/scpwps/ecb.wp2832~51322fbd6a.en.pdf
# This is just a simple attempt, not a reproduction of the article.
for column in df.columns:
    y = df[column]
    print(f'\n\nFitting model of: {column}')

    # Initialize optimal parameters and maximum loss function
    best_rmse = float('inf')
    
    # define level, trend, seasonal, cycle, autoregressive
    for i in range(4):
        model = UnobservedComponents(y,
                                     level='smooth trend',
                                     seasonal=4,
                                     cycle=True,
                                     autoregressive=i)
        
        # fit model
        result = model.fit()
        
        # predict
        y_pred = result.fittedvalues
        rmse = func_calc_rmse(y, y_pred)
        
        # Update optimal parameters
        if rmse < best_rmse:
            best_rmse = rmse
            best_result = result
            pr_in = y_pred
            pr_out = best_result.forecast(steps=12)
            
    print(best_result.summary())
    pr = pd.DataFrame({column:pd.concat([pr_in, pr_out])})
    predict_data = predict_data.merge(pr, left_index=True, right_index=True, how='left')

# Output prediction results
predict_data = macro_data.combine_first(predict_data) # This does not change the value of historical data
# predict_data = macro_data_fitted.combine_first(predict_data) # If you want to use filtered historical values
predict_data.to_csv(f'./3.4_predict_data.csv')

dur = (time.perf_counter() - start_t) / 60
print(f'\nThe prediction process took a total of {dur:,.2f} minutes.')
# Out:
# macrofoctor_list：['GDP_Const_Qtr' 'Ind_Pro_Mth' 'CPI_Mth' 'Core_CPI_Mth' 'PPI_Mth'
#  'FAI_Cum' 'Retail_Sales_Mth' 'Imports_Mth' 'Exports_Mth' 'M1' 'M2'
#  'Loans_RMB' 'Social_Financing' 'Manuf_PMI' 'Ind_Revenue_Cum' 'PPIRM_Mth'
#  'CGPI_Mth' '70_Cities_Price_Mth' 'Power_Gen_Mth' 'Freight_Mth'
#  'Urban_Income_Cum' 'Urban_Exp_Cum' 'Nat_Housing_Index' 'Macro_Eco_Index'
#  'Housing_Sales_Cum']
#
#
# Fitting model of: GDP_Const_Qtr
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                GDP_Const_Qtr   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -29.759
#                    + stochastic seasonal(4)   AIC                             75.518
#                                     + cycle   BIC                             91.721
#                                     + AR(3)   HQIC                            81.800
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:43
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular     0.0233      0.026      0.910      0.363      -0.027       0.073
# sigma2.trend         0.0005      0.001      0.840      0.401      -0.001       0.002
# sigma2.seasonal   1.334e-09      0.006    2.1e-07      1.000      -0.012       0.012
# sigma2.ar            0.0399      0.033      1.205      0.228      -0.025       0.105
# frequency.cycle      0.7158      0.068     10.581      0.000       0.583       0.848
# ar.L1               -0.5598      0.260     -2.153      0.031      -1.069      -0.050
# ar.L2               -0.5752      0.190     -3.024      0.002      -0.948      -0.202
# ar.L3               -0.7219      0.262     -2.751      0.006      -1.236      -0.208
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.30   Jarque-Bera (JB):                50.48
# Prob(Q):                              0.58   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.36   Skew:                            -0.34
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Ind_Pro_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                  Ind_Pro_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -15.732
#                    + stochastic seasonal(4)   AIC                             45.463
#                                     + cycle   BIC                             59.641
#                                     + AR(2)   HQIC                            50.960
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:44
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  4.988e-12      0.016   3.14e-10      1.000      -0.031       0.031
# sigma2.trend         0.0009      0.001      1.395      0.163      -0.000       0.002
# sigma2.seasonal      0.0085      0.006      1.349      0.177      -0.004       0.021
# sigma2.ar            0.0195      0.015      1.298      0.194      -0.010       0.049
# frequency.cycle      0.6142      0.040     15.534      0.000       0.537       0.692
# ar.L1               -0.0081      0.162     -0.050      0.960      -0.325       0.309
# ar.L2               -0.8034      0.332     -2.420      0.016      -1.454      -0.153
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.41   Jarque-Bera (JB):                 0.39
# Prob(Q):                              0.52   Prob(JB):                         0.82
# Heteroskedasticity (H):               0.34   Skew:                            -0.19
# Prob(H) (two-sided):                  0.02   Kurtosis:                         2.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: CPI_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                      CPI_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                -134.487
#                    + stochastic seasonal(4)   AIC                            276.974
#                                     + cycle   BIC                            285.075
# Date:                      Tue, 17 Dec 2024   HQIC                           280.115
# Time:                              16:43:44
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular     3.2370      0.786      4.116      0.000       1.696       4.779
# sigma2.trend         0.0254      0.029      0.866      0.386      -0.032       0.083
# sigma2.seasonal      0.5248      0.399      1.317      0.188      -0.256       1.306
# frequency.cycle      0.9587      0.317      3.029      0.002       0.338       1.579
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               608.71
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):             956.56   Skew:                            -3.45
# Prob(H) (two-sided):                  0.00   Kurtosis:                        17.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Core_CPI_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                 Core_CPI_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                   9.331
#                    + stochastic seasonal(4)   AIC                             -6.661
#                                     + cycle   BIC                              5.491
#                                     + AR(1)   HQIC                            -1.950
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:45
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  1.175e-10      0.001   1.42e-07      1.000      -0.002       0.002
# sigma2.trend       1.67e-05   1.77e-05      0.944      0.345    -1.8e-05    5.14e-05
# sigma2.seasonal      0.0008      0.001      1.322      0.186      -0.000       0.002
# sigma2.ar         4.323e-12      0.000   9.58e-09      1.000      -0.001       0.001
# frequency.cycle      0.1582      0.022      7.087      0.000       0.114       0.202
# ar.L1                0.4960   1.92e-12   2.59e+11      0.000       0.496       0.496
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):                29.11
# Prob(Q):                              0.76   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.71   Skew:                            -1.24
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.87e+35. Standard errors may be unstable.
#
#
# Fitting model of: PPI_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                      PPI_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -10.892
#                    + stochastic seasonal(4)   AIC                             29.784
#                                     + cycle   BIC                             37.886
# Date:                      Tue, 17 Dec 2024   HQIC                            32.925
# Time:                              16:43:46
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  9.828e-11      0.005   2.01e-08      1.000      -0.010       0.010
# sigma2.trend         0.0043      0.002      1.943      0.052   -3.82e-05       0.009
# sigma2.seasonal      0.0125      0.004      3.335      0.001       0.005       0.020
# frequency.cycle      0.2926      0.060      4.870      0.000       0.175       0.410
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.21   Jarque-Bera (JB):                 2.23
# Prob(Q):                              0.07   Prob(JB):                         0.33
# Heteroskedasticity (H):               0.20   Skew:                             0.48
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: FAI_Cum
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                      FAI_Cum   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -68.337
#                    + stochastic seasonal(4)   AIC                            148.673
#                                     + cycle   BIC                            160.826
#                                     + AR(1)   HQIC                           153.385
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:46
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular     0.2504      0.074      3.396      0.001       0.106       0.395
# sigma2.trend         0.0038      0.002      1.620      0.105      -0.001       0.008
# sigma2.seasonal      0.0132      0.012      1.129      0.259      -0.010       0.036
# sigma2.ar         1.174e-09      0.066   1.77e-08      1.000      -0.130       0.130
# frequency.cycle      0.5558      0.099      5.598      0.000       0.361       0.750
# ar.L1                0.6759    2.7e-10   2.51e+09      0.000       0.676       0.676
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 7.84
# Prob(Q):                              0.93   Prob(JB):                         0.02
# Heteroskedasticity (H):               6.45   Skew:                             0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.48e+33. Standard errors may be unstable.
#
#
# Fitting model of: Retail_Sales_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:             Retail_Sales_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -64.928
#                    + stochastic seasonal(4)   AIC                            145.857
#                                     + cycle   BIC                            162.060
#                                     + AR(3)   HQIC                           152.139
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:47
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  1.678e-05      0.111      0.000      1.000      -0.218       0.218
# sigma2.trend         0.0012      0.001      0.992      0.321      -0.001       0.004
# sigma2.seasonal      0.0568      0.046      1.236      0.216      -0.033       0.147
# sigma2.ar            0.1834      0.123      1.488      0.137      -0.058       0.425
# frequency.cycle      0.7795      0.260      2.993      0.003       0.269       1.290
# ar.L1                0.3188      0.414      0.771      0.441      -0.492       1.130
# ar.L2               -0.8898      0.247     -3.609      0.000      -1.373      -0.407
# ar.L3                0.3633      0.448      0.812      0.417      -0.514       1.241
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                15.28
# Prob(Q):                              0.65   Prob(JB):                         0.00
# Heteroskedasticity (H):              17.00   Skew:                             0.83
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Imports_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                  Imports_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                -119.187
#                    + stochastic seasonal(4)   AIC                            246.375
#                                     + cycle   BIC                            254.476
# Date:                      Tue, 17 Dec 2024   HQIC                           249.516
# Time:                              16:43:47
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  3.794e-10      0.259   1.46e-09      1.000      -0.508       0.508
# sigma2.trend         0.0597      0.038      1.557      0.120      -0.015       0.135
# sigma2.seasonal      1.3076      0.364      3.595      0.000       0.595       2.020
# frequency.cycle      0.7133      0.039     18.366      0.000       0.637       0.789
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.22   Jarque-Bera (JB):                 0.74
# Prob(Q):                              0.27   Prob(JB):                         0.69
# Heteroskedasticity (H):               0.31   Skew:                             0.13
# Prob(H) (two-sided):                  0.02   Kurtosis:                         2.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Exports_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                  Exports_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                -117.588
#                    + stochastic seasonal(4)   AIC                            249.175
#                                     + cycle   BIC                            263.352
#                                     + AR(2)   HQIC                           254.672
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:47
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  3.354e-11      0.904   3.71e-11      1.000      -1.772       1.772
# sigma2.trend         0.0375      0.026      1.418      0.156      -0.014       0.089
# sigma2.seasonal      1.5893      0.418      3.799      0.000       0.769       2.409
# sigma2.ar         3.343e-11      0.685   4.88e-11      1.000      -1.343       1.343
# frequency.cycle      0.9434      0.040     23.580      0.000       0.865       1.022
# ar.L1                0.5294   1.36e-11    3.9e+10      0.000       0.529       0.529
# ar.L2                0.3926   5.08e-11   7.72e+09      0.000       0.393       0.393
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.28   Jarque-Bera (JB):                 3.13
# Prob(Q):                              0.07   Prob(JB):                         0.21
# Heteroskedasticity (H):               0.18   Skew:                             0.46
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.24e+37. Standard errors may be unstable.
#
#
# Fitting model of: M1
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                           M1   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -42.175
#                    + stochastic seasonal(4)   AIC                             98.351
#                                     + cycle   BIC                            112.528
#                                     + AR(2)   HQIC                           103.847
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:48
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  1.321e-12      0.031   4.33e-11      1.000      -0.060       0.060
# sigma2.trend         0.0148      0.008      1.862      0.063      -0.001       0.030
# sigma2.seasonal      0.0406      0.014      2.837      0.005       0.013       0.069
# sigma2.ar         7.454e-13      0.031   2.37e-11      1.000      -0.062       0.062
# frequency.cycle      0.5652      0.075      7.505      0.000       0.418       0.713
# ar.L1                0.6682   1.77e-14   3.77e+13      0.000       0.668       0.668
# ar.L2                0.0904   9.47e-14   9.54e+11      0.000       0.090       0.090
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.58   Jarque-Bera (JB):                 0.83
# Prob(Q):                              0.44   Prob(JB):                         0.66
# Heteroskedasticity (H):               0.90   Skew:                            -0.23
# Prob(H) (two-sided):                  0.82   Kurtosis:                         2.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.65e+40. Standard errors may be unstable.
#
#
# Fitting model of: M2
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                           M2   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -17.594
#                    + stochastic seasonal(4)   AIC                             43.189
#                                     + cycle   BIC                             51.290
# Date:                      Tue, 17 Dec 2024   HQIC                            46.329
# Time:                              16:43:48
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  2.703e-11      0.007   3.79e-09      1.000      -0.014       0.014
# sigma2.trend         0.0015      0.001      2.172      0.030       0.000       0.003
# sigma2.seasonal      0.0257      0.008      3.404      0.001       0.011       0.040
# frequency.cycle      0.5447      0.046     11.942      0.000       0.455       0.634
# ===================================================================================
# Ljung-Box (L1) (Q):                   5.13   Jarque-Bera (JB):                 5.67
# Prob(Q):                              0.02   Prob(JB):                         0.06
# Heteroskedasticity (H):               0.30   Skew:                             0.51
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Loans_RMB
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                    Loans_RMB   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                   2.718
#                    + stochastic seasonal(4)   AIC                              2.564
#                                     + cycle   BIC                             10.665
# Date:                      Tue, 17 Dec 2024   HQIC                             5.705
# Time:                              16:43:49
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  3.826e-10      0.005   8.19e-08      1.000      -0.009       0.009
# sigma2.trend         0.0005      0.000      1.526      0.127      -0.000       0.001
# sigma2.seasonal      0.0144      0.004      3.398      0.001       0.006       0.023
# frequency.cycle      0.6981      0.068     10.283      0.000       0.565       0.831
# ===================================================================================
# Ljung-Box (L1) (Q):                   9.31   Jarque-Bera (JB):                50.71
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.11   Skew:                            -0.54
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Social_Financing
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:             Social_Financing   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -87.416
#                    + stochastic seasonal(4)   AIC                            182.833
#                                     + cycle   BIC                            190.934
# Date:                      Tue, 17 Dec 2024   HQIC                           185.974
# Time:                              16:43:49
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular     0.0597      0.026      2.288      0.022       0.009       0.111
# sigma2.trend         0.0700      0.037      1.916      0.055      -0.002       0.142
# sigma2.seasonal   2.171e-11      0.003   6.77e-09      1.000      -0.006       0.006
# frequency.cycle      0.4013      0.063      6.402      0.000       0.278       0.524
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.80   Jarque-Bera (JB):                 5.51
# Prob(Q):                              0.37   Prob(JB):                         0.06
# Heteroskedasticity (H):              15.18   Skew:                             0.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Manuf_PMI
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                    Manuf_PMI   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -16.017
#                    + stochastic seasonal(4)   AIC                             48.035
#                                     + cycle   BIC                             64.238
#                                     + AR(3)   HQIC                            54.317
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:50
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  2.378e-09      0.011   2.18e-07      1.000      -0.021       0.021
# sigma2.trend         0.0010      0.001      1.877      0.060   -4.57e-05       0.002
# sigma2.seasonal      0.0210      0.012      1.783      0.075      -0.002       0.044
# sigma2.ar            0.0033      0.013      0.261      0.794      -0.022       0.028
# frequency.cycle      0.5505      0.043     12.814      0.000       0.466       0.635
# ar.L1               -0.4051      2.526     -0.160      0.873      -5.356       4.546
# ar.L2               -0.4521      1.339     -0.338      0.736      -3.077       2.173
# ar.L3               -0.8218      2.424     -0.339      0.735      -5.573       3.929
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.57   Jarque-Bera (JB):                14.13
# Prob(Q):                              0.21   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.62   Skew:                             0.53
# Prob(H) (two-sided):                  0.31   Kurtosis:                         5.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Ind_Revenue_Cum
# C:\Program Files\Python39\lib\site-packages\statsmodels\tsa\stattools.py:1363: RuntimeWarning: divide by zero encountered in divide
#   test_statistic = numer_squared_sum / denom_squared_sum
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:              Ind_Revenue_Cum   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -89.210
#                    + stochastic seasonal(4)   AIC                            192.421
#                                     + cycle   BIC                            206.598
#                                     + AR(2)   HQIC                           197.917
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:50
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  7.215e-11      0.336   2.15e-10      1.000      -0.658       0.658
# sigma2.trend         0.0019      0.004      0.511      0.609      -0.005       0.009
# sigma2.seasonal      0.2798      0.128      2.180      0.029       0.028       0.531
# sigma2.ar         1.155e-12      0.158   7.29e-12      1.000      -0.311       0.311
# frequency.cycle      0.2637      0.050      5.283      0.000       0.166       0.362
# ar.L1                0.4718   9.37e-13   5.04e+11      0.000       0.472       0.472
# ar.L2               -0.1515   6.42e-13  -2.36e+11      0.000      -0.152      -0.152
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.03   Jarque-Bera (JB):                 7.55
# Prob(Q):                              0.31   Prob(JB):                         0.02
# Heteroskedasticity (H):                inf   Skew:                            -0.33
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.57e+40. Standard errors may be unstable.
#
#
# Fitting model of: PPIRM_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                    PPIRM_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -28.205
#                    + stochastic seasonal(4)   AIC                             64.410
#                                     + cycle   BIC                             72.511
# Date:                      Tue, 17 Dec 2024   HQIC                            67.551
# Time:                              16:43:50
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  9.965e-11      0.014   6.94e-09      1.000      -0.028       0.028
# sigma2.trend         0.0114      0.005      2.261      0.024       0.002       0.021
# sigma2.seasonal      0.0216      0.008      2.837      0.005       0.007       0.037
# frequency.cycle      0.6141      0.053     11.675      0.000       0.511       0.717
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.93   Jarque-Bera (JB):                12.87
# Prob(Q):                              0.16   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.11   Skew:                             1.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: CGPI_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                     CGPI_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -11.488
#                    + stochastic seasonal(4)   AIC                             30.976
#                                     + cycle   BIC                             39.077
# Date:                      Tue, 17 Dec 2024   HQIC                            34.117
# Time:                              16:43:51
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  6.463e-11      0.007   9.46e-09      1.000      -0.013       0.013
# sigma2.trend         0.0051      0.002      2.464      0.014       0.001       0.009
# sigma2.seasonal      0.0123      0.004      2.928      0.003       0.004       0.020
# frequency.cycle      0.4820      0.123      3.907      0.000       0.240       0.724
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.37   Jarque-Bera (JB):                 0.03
# Prob(Q):                              0.12   Prob(JB):                         0.98
# Heteroskedasticity (H):               0.41   Skew:                             0.04
# Prob(H) (two-sided):                  0.06   Kurtosis:                         2.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: 70_Cities_Price_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:          70_Cities_Price_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                   5.323
#                    + stochastic seasonal(4)   AIC                              5.354
#                                     + cycle   BIC                             21.557
#                                     + AR(3)   HQIC                            11.636
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:51
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  2.268e-10      0.005      5e-08      1.000      -0.009       0.009
# sigma2.trend         0.0055      0.004      1.469      0.142      -0.002       0.013
# sigma2.seasonal      0.0043      0.002      2.370      0.018       0.001       0.008
# sigma2.ar         2.504e-12      0.005   5.04e-10      1.000      -0.010       0.010
# frequency.cycle      0.5610      0.188      2.991      0.003       0.193       0.929
# ar.L1                1.1815   1.33e-12   8.91e+11      0.000       1.182       1.182
# ar.L2               -0.3879   1.12e-13  -3.45e+12      0.000      -0.388      -0.388
# ar.L3                0.1483   4.72e-12   3.14e+10      0.000       0.148       0.148
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.85   Jarque-Bera (JB):                 3.12
# Prob(Q):                              0.09   Prob(JB):                         0.21
# Heteroskedasticity (H):               1.42   Skew:                            -0.46
# Prob(H) (two-sided):                  0.45   Kurtosis:                         3.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.5e+39. Standard errors may be unstable.
#
#
# Fitting model of: Power_Gen_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                Power_Gen_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -66.223
#                    + stochastic seasonal(4)   AIC                            148.447
#                                     + cycle   BIC                            164.650
#                                     + AR(3)   HQIC                           154.729
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:52
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  2.702e-07      0.106   2.54e-06      1.000      -0.208       0.208
# sigma2.trend         0.0036      0.003      1.311      0.190      -0.002       0.009
# sigma2.seasonal      0.1055      0.051      2.049      0.040       0.005       0.206
# sigma2.ar            0.0780      0.122      0.637      0.524      -0.162       0.318
# frequency.cycle      0.5672      0.028     19.963      0.000       0.512       0.623
# ar.L1                0.1086      0.970      0.112      0.911      -1.793       2.010
# ar.L2               -0.7854      0.348     -2.254      0.024      -1.468      -0.102
# ar.L3                0.4379      0.925      0.473      0.636      -1.376       2.251
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.43   Jarque-Bera (JB):                 1.37
# Prob(Q):                              0.51   Prob(JB):                         0.50
# Heteroskedasticity (H):               0.29   Skew:                             0.20
# Prob(H) (two-sided):                  0.01   Kurtosis:                         2.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Freight_Mth
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                  Freight_Mth   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                -140.411
#                    + stochastic seasonal(4)   AIC                            294.822
#                                     + cycle   BIC                            309.000
#                                     + AR(2)   HQIC                           300.319
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:52
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  1.017e-08     25.137   4.04e-10      1.000     -49.267      49.267
# sigma2.trend      3.684e-11      0.004   9.08e-09      1.000      -0.008       0.008
# sigma2.seasonal      0.0842      0.316      0.266      0.790      -0.535       0.704
# sigma2.ar           13.3816     26.254      0.510      0.610     -38.076      64.839
# frequency.cycle      0.5356      0.074      7.234      0.000       0.391       0.681
# ar.L1                0.2801      0.382      0.733      0.464      -0.469       1.029
# ar.L2                0.2275      0.371      0.613      0.540      -0.500       0.955
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.91   Jarque-Bera (JB):                 4.22
# Prob(Q):                              0.34   Prob(JB):                         0.12
# Heteroskedasticity (H):               1.37   Skew:                             0.42
# Prob(H) (two-sided):                  0.49   Kurtosis:                         4.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Urban_Income_Cum
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:             Urban_Income_Cum   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                  19.813
#                    + stochastic seasonal(4)   AIC                            -23.625
#                                     + cycle   BIC                             -7.422
#                                     + AR(3)   HQIC                           -17.343
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:53
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  7.553e-08      0.002   3.03e-05      1.000      -0.005       0.005
# sigma2.trend         0.0003      0.000      1.205      0.228      -0.000       0.001
# sigma2.seasonal      0.0012      0.001      1.376      0.169      -0.001       0.003
# sigma2.ar            0.0061      0.004      1.668      0.095      -0.001       0.013
# frequency.cycle      0.4897      0.040     12.221      0.000       0.411       0.568
# ar.L1                0.5351      0.596      0.898      0.369      -0.633       1.704
# ar.L2               -0.8566      0.234     -3.665      0.000      -1.315      -0.398
# ar.L3                0.4052      0.613      0.661      0.509      -0.796       1.607
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 2.68
# Prob(Q):                              0.90   Prob(JB):                         0.26
# Heteroskedasticity (H):               0.29   Skew:                            -0.50
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Urban_Exp_Cum
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:                Urban_Exp_Cum   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -27.207
#                    + stochastic seasonal(4)   AIC                             62.414
#                                     + cycle   BIC                             70.515
# Date:                      Tue, 17 Dec 2024   HQIC                            65.555
# Time:                              16:43:53
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular     0.0004      0.006      0.071      0.944      -0.012       0.012
# sigma2.trend         0.0010      0.001      1.631      0.103      -0.000       0.002
# sigma2.seasonal      0.0509      0.011      4.475      0.000       0.029       0.073
# frequency.cycle      1.0289      0.059     17.329      0.000       0.913       1.145
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.35   Jarque-Bera (JB):                 6.17
# Prob(Q):                              0.56   Prob(JB):                         0.05
# Heteroskedasticity (H):               2.43   Skew:                             0.48
# Prob(H) (two-sided):                  0.06   Kurtosis:                         4.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Nat_Housing_Index
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:            Nat_Housing_Index   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -25.830
#                    + stochastic seasonal(4)   AIC                             59.659
#                                     + cycle   BIC                             67.760
# Date:                      Tue, 17 Dec 2024   HQIC                            62.800
# Time:                              16:43:54
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  5.039e-11      0.010   4.82e-09      1.000      -0.020       0.020
# sigma2.trend         0.0058      0.003      1.742      0.081      -0.001       0.012
# sigma2.seasonal      0.0258      0.005      5.390      0.000       0.016       0.035
# frequency.cycle      0.6046      0.265      2.277      0.023       0.084       1.125
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.65   Jarque-Bera (JB):                 9.45
# Prob(Q):                              0.03   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.24   Skew:                            -0.56
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Macro_Eco_Index
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:              Macro_Eco_Index   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                 -25.068
#                    + stochastic seasonal(4)   AIC                             66.137
#                                     + cycle   BIC                             82.340
#                                     + AR(3)   HQIC                            72.419
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:54
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular     0.0001      0.019      0.008      0.994      -0.036       0.036
# sigma2.trend         0.0026      0.002      1.556      0.120      -0.001       0.006
# sigma2.seasonal      0.0076      0.005      1.691      0.091      -0.001       0.016
# sigma2.ar            0.0287      0.015      1.930      0.054      -0.000       0.058
# frequency.cycle      1.0162      0.114      8.929      0.000       0.793       1.239
# ar.L1                0.0680      0.437      0.155      0.876      -0.789       0.925
# ar.L2               -0.8886      0.186     -4.778      0.000      -1.253      -0.524
# ar.L3                0.0168      0.425      0.040      0.968      -0.817       0.850
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 3.65
# Prob(Q):                              0.96   Prob(JB):                         0.16
# Heteroskedasticity (H):               0.50   Skew:                            -0.51
# Prob(H) (two-sided):                  0.13   Kurtosis:                         3.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# Fitting model of: Housing_Sales_Cum
#                            Unobserved Components Results
# ====================================================================================
# Dep. Variable:            Housing_Sales_Cum   No. Observations:                   63
# Model:                         smooth trend   Log Likelihood                -130.722
#                    + stochastic seasonal(4)   AIC                            273.444
#                                     + cycle   BIC                            285.596
#                                     + AR(1)   HQIC                           278.156
# Date:                      Tue, 17 Dec 2024
# Time:                              16:43:55
# Sample:                          03-31-2010
#                                - 09-30-2025
# Covariance Type:                        opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular  1.404e-08      0.853   1.64e-08      1.000      -1.673       1.673
# sigma2.trend         0.0424      0.034      1.265      0.206      -0.023       0.108
# sigma2.seasonal      2.7340      0.733      3.729      0.000       1.297       4.171
# sigma2.ar         3.814e-10      0.437   8.73e-10      1.000      -0.856       0.856
# frequency.cycle      0.6009      0.033     18.009      0.000       0.535       0.666
# ar.L1                0.9742   7.48e-11    1.3e+10      0.000       0.974       0.974
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.85   Jarque-Bera (JB):                 0.10
# Prob(Q):                              0.17   Prob(JB):                         0.95
# Heteroskedasticity (H):               1.78   Skew:                             0.06
# Prob(H) (two-sided):                  0.22   Kurtosis:                         2.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.27e+35. Standard errors may be unstable.
#
# The prediction process took a total of 0.19 minutes.
